# %%
import ase

# %%
from pathlib import Path

# %%
import numpy as np

# %%
_ = np.load("../dcm_mp2_psf_order.npz")

# %%
_
# Out:
# NpzFile '../dcm_mp2_psf_order.npz' with keys: N, E, Q, D, F...

# %%
_["Z"]
# Out:
# array([[ 6, 17, 17, ...,  0,  0,  0],
#        [ 6, 17, 17, ...,  0,  0,  0],
#        [ 6, 17, 17, ...,  0,  0,  0],
#        ...,
#        [ 6, 17, 17, ..., 17,  1,  1],
#        [ 6, 17, 17, ..., 17,  1,  1],
#        [ 6, 17, 17, ..., 17,  1,  1]], shape=(41950, 10), dtype=int32)
