# %%
import numpy as np
from pathlib import Path

data_files = {str(x): np.load(x) for x in Path("/pchem-data/meuwly/boittier/home").glob("out_men*npz")}

# %%
data_files
# Out:
# {'/pchem-data/meuwly/boittier/home/out_mensh.npz': NpzFile '/pchem-data/meuwly/boittier/home/out_mensh.npz' with keys: R, D, N, Z, Dxyz...,
#  '/pchem-data/meuwly/boittier/home/out_mensh3.npz': NpzFile '/pchem-data/meuwly/boittier/home/out_mensh3.npz' with keys: R, D, N, E, Z...,
#  '/pchem-data/meuwly/boittier/home/out_mensh0.npz': NpzFile '/pchem-data/meuwly/boittier/home/out_mensh0.npz' with keys: R, D, N, E, Z...,
#  '/pchem-data/meuwly/boittier/home/out_mensh4.npz': NpzFile '/pchem-data/meuwly/boittier/home/out_mensh4.npz' with keys: R, D, N, E, Z...,
#  '/pchem-data/meuwly/boittier/home/out_mensh1.npz': NpzFile '/pchem-data/meuwly/boittier/home/out_mensh1.npz' with keys: R, D, N, E, Z...,
#  '/pchem-data/meuwly/boittier/home/out_mensh2.npz': NpzFile '/pchem-data/meuwly/boittier/home/out_mensh2.npz' with keys: R, D, N, E, Z...}

# %%
_ = data_files["/pchem-data/meuwly/boittier/home/out_mensh.npz"]

# %%
list(_.keys())
# Out:
# ['R', 'D', 'N', 'Z', 'Dxyz', 'F', 'esp', 'esp_grid', 'n_sample']

# %%
from trainer import *

ROOT = "/pchem-data/meuwly/boittier/home/"
args = NotebookArgs(
    train_efd=Path(ROOT + "out_mensh0.npz.npz"),
    train_grid=Path(ROOT + "out_mensh0.npz.npz"),
    valid_efd=Path(ROOT + "out_mensh1.npz.npz"),
    valid_grid=Path(ROOT + "out_mensh1.npz.npz"),
    output_dir=Path("./output"),
    batch_size=10,
    epochs=5,
    learning_rate=5e-4,
)
# Out:
# W0113 11:43:08.377212    8669 platform_util.cc:218] unable to create StreamExecutor for CUDA:0: CUDA error: : CUDA_ERROR_DEVICE_UNAVAILABLE: CUDA-capable device(s) is/are busy or unavailable
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from trainer import *
#       3 ROOT = "/pchem-data/meuwly/boittier/home/"
#       4 args = NotebookArgs(
#       5     train_efd=Path(ROOT + "out_mensh0.npz.npz"),
#       6     train_grid=Path(ROOT + "out_mensh0.npz.npz"),
#    (...)     12     learning_rate=5e-4,
#      13 )
#
# File ~/mmml/examples/menshutkin/trainer.py:39
#      37 import jax.numpy as jnp
#      38 from mmml.dcmnet.dcmnet.modules import MessagePassingModel
# ---> 39 from mmml.dcmnet.dcmnet.training import train_model
#      40 from mmml.dcmnet.dcmnet.data import prepare_datasets
#      42 CLI_PATH_FIELDS = {
#      43     "train_efd",
#      44     "train_grid",
#    (...)     48     "restart",
#      49 }
#
# File ~/mmml/mmml/dcmnet/dcmnet/training.py:12
#      10 import optax
#      11 import numpy as np
# ---> 12 from .loss import esp_mono_loss
#      13 from .electrostatics import calc_esp
#      15 from .data import prepare_batches, prepare_datasets
#
# File ~/mmml/mmml/dcmnet/dcmnet/loss.py:44
#      40     return dipole_out * 1.88873
#      41     # return jnp.linalg.norm(dipole_out)* 4.80320
# ---> 44 @functools.partial(jax.jit, static_argnames=("batch_size", "esp_w", "chg_w", "n_dcm", "distance_weighting", "distance_scale", "distance_min", "esp_magnitude_weighting", "esp_min_distance", "esp_max_value", "use_atomic_radii_mask", "charge_conservation_w", "esp_grid_units", "radii_cutoff_multiplier"))
#      45 def esp_mono_loss(
#      46     dipo_prediction,
#      47     mono_prediction,
#      48     esp_target,
#      49     vdw_surface,
#      50     mono,
#      51     ngrid,
#      52     n_atoms,
#      53     batch_size,
#      54     esp_w,
#      55     chg_w,
#      56     n_dcm,
#      57     atom_positions=None,
#      58     atomic_numbers=None,
#      59     atom_mask=None,
#      60     distance_weighting=False,
#      61     distance_scale=2.0,
#      62     distance_min=0.5,
#      63     esp_magnitude_weighting=False,
#      64     esp_min_distance=0.0,
#      65     esp_max_value=1e10,
#      66     use_atomic_radii_mask=True,
#      67     charge_conservation_w=1.0,
#      68 ):
#      69     """
#      70     Combined ESP and monopole loss function for DCMNet training.
#      71
#    (...)    144         - esp_mask: mask indicating valid ESP points (1.0 = valid, 0.0 = masked)
#     145     """
#     146     # sum_of_dc_monopoles = mono_prediction.sum(axis=-1)
#     147     # l2_loss_mono = optax.l2_loss(sum_of_dc_monopoles, mono)
#     148     # mono_loss = jnp.mean(l2_loss_mono)
#    (...)    154     # return esp_loss + mono_loss
#     155     # Ensure scalar n_atoms even if shaped (1,) or (1,1)
#
# File ~/.conda/envs/mmml-gpu/lib/python3.12/site-packages/jax/_src/api.py:312, in jit(fun, in_shardings, out_shardings, static_argnums, static_argnames, donate_argnums, donate_argnames, keep_unused, device, backend, inline, abstracted_axes, compiler_options)
#     172 def jit(
#     173   fun: Callable, /, *,
#     174   in_shardings: Any = sharding_impls.UNSPECIFIED,
#    (...)    185   compiler_options: dict[str, Any] | None = None,
#     186 ) -> pjit.JitWrapped:
#     187   """Sets up ``fun`` for just-in-time compilation with XLA.
#     188
#     189   Args:
#    (...)    310     Array([   0,    1,  256, 6561], dtype=int32)
#     311   """
# --> 312   return pjit.make_jit(
#     313       fun, in_shardings=in_shardings, out_shardings=out_shardings,
#     314       static_argnums=static_argnums, static_argnames=static_argnames,
#     315       donate_argnums=donate_argnums, donate_argnames=donate_argnames,
#     316       keep_unused=keep_unused, device=device, backend=backend, inline=inline,
#     317       abstracted_axes=abstracted_axes, compiler_options=compiler_options,
#     318       use_resource_env=False)
#
# File ~/.conda/envs/mmml-gpu/lib/python3.12/site-packages/jax/_src/pjit.py:451, in make_jit(fun, in_shardings, out_shardings, static_argnums, static_argnames, donate_argnums, donate_argnames, keep_unused, device, backend, inline, abstracted_axes, compiler_options, use_resource_env)
#     435 def make_jit(fun: Callable,
#     436              *,
#     437              in_shardings: Any,
#    (...)    448              compiler_options: dict[str, Any] | None,
#     449              use_resource_env: bool) -> Any:
#     450   """jit() and pjit() are thin wrappers around this function."""
# --> 451   jit_info = _parse_jit_arguments(
#     452         fun, in_shardings=in_shardings, out_shardings=out_shardings,
#     453         static_argnums=static_argnums, static_argnames=static_argnames,
#     454         donate_argnums=donate_argnums, donate_argnames=donate_argnames,
#     455         keep_unused=keep_unused, device=device, backend=backend, inline=inline,
#     456         abstracted_axes=abstracted_axes, compiler_options=compiler_options,
#     457         use_resource_env=use_resource_env)
#     458   return _cpp_pjit(fun, jit_info)
#
# File ~/.conda/envs/mmml-gpu/lib/python3.12/site-packages/jax/_src/pjit.py:409, in _parse_jit_arguments(fun, in_shardings, out_shardings, static_argnums, static_argnames, donate_argnums, donate_argnames, keep_unused, device, backend, inline, abstracted_axes, compiler_options, use_resource_env)
#     406 fun_sourceinfo = api_util.fun_sourceinfo(fun)
#     407 fun_signature = api_util.fun_signature(fun)
# --> 409 donate_argnums, donate_argnames, static_argnums, static_argnames = resolve_argnums(
#     410     fun, fun_signature, donate_argnums, donate_argnames, static_argnums,
#     411     static_argnames)
#     413 compiler_options_kvs = (() if compiler_options is None else
#     414                         tuple(compiler_options.items()))
#     415 return PjitInfo(
#     416       fun_sourceinfo=fun_sourceinfo,
#     417       fun_signature=fun_signature,
#    (...)    432       use_resource_env=use_resource_env,
#     433       compiler_options_kvs=compiler_options_kvs)
#
# File ~/.conda/envs/mmml-gpu/lib/python3.12/site-packages/jax/_src/api_util.py:541, in resolve_argnums(fun, signature, donate_argnums, donate_argnames, static_argnums, static_argnames)
#     539 # Validation
#     540 _validate_argnums(signature, static_argnums, "static_argnums")
# --> 541 _validate_argnames(signature, static_argnames, "static_argnames")
#     542 _validate_argnums(signature, donate_argnums, "donate_argnums")
#     543 _validate_argnames(signature, donate_argnames, "donate_argnames")
#
# File ~/.conda/envs/mmml-gpu/lib/python3.12/site-packages/jax/_src/api_util.py:200, in _validate_argnames(sig, argnames, argnames_name)
#     198 # Check that all argnames exist on function
#     199 if invalid_argnames := (set(argnames) - valid_kwargs):
# --> 200   raise ValueError(f"Jitted function has invalid argnames {invalid_argnames} "
#     201                    f"in {argnames_name}. Function does not take these args.")
#
# ValueError: Jitted function has invalid argnames {'radii_cutoff_multiplier', 'esp_grid_units'} in static_argnames. Function does not take these args.
