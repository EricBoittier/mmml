# %%
import mmml
import ase
import numpy as np

# %%
from mmml.interfaces.pycharmmInterface.mm_system_energy import (
    CharmmNbondSettings,
    mm_system_energy_and_forces,
)
# Out:
# ╭───────────────────────────────────────────── PyCHARMM environment ──────────────────────────────────────────────╮
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓ │
# │ ┃ Field                  ┃ Value                                                                              ┃ │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩ │
# │ │ CGENFF RTF             │ /home/ericb/mmml/mmml/data/charmm/top_all36_cgenff.rtf                             │ │
# │ │ CGENFF PRM             │ /home/ericb/mmml/mmml/data/charmm/par_all36_cgenff.prm                             │ │
# │ │ CHARMM_HOME            │ /home/ericb/mmml/setup/charmm                                                      │ │
# │ │ CHARMM_LIB_DIR         │ /home/ericb/mmml/setup/charmm                                                      │ │
# │ └────────────────────────┴────────────────────────────────────────────────────────────────────────────────────┘ │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
from pathlib import Path
from mmml.interfaces.pycharmmInterface.import_pycharmm import ensure_pycharmm_loaded
ensure_pycharmm_loaded()
from mmml.interfaces.pycharmmInterface.trialanine_water_box import build_trialanine_water_box_in_charmm
box = build_trialanine_water_box_in_charmm(n_waters=10, box_side_A=28.0, seed=11, workdir=Path('/tmp/tria_box'))
print(len(box.positions), box.psf_path)# ase.Atoms()
positions = box.positions
box

# %%
from mmml.interfaces.pycharmmInterface.cgenff_bonded_reference import (
    charmm_bonded_forces_kcalmol_A,
    charmm_nonbonded_energy_components_kcalmol,
    run_charmm_nonbonded_ener_force,
    set_charmm_positions,
    setup_nonbonded_only_charmm,
)
from mmml.interfaces.pycharmmInterface.mm_system_energy import (
    load_nonbonded_system_from_charmm,
    nonbonded_energy_and_forces,
)


pos = np.asarray(positions, dtype=np.float64)
set_charmm_positions(pos)

# %%
from mmml.interfaces.pycharmmInterface import import_pycharmm
import_pycharmm.view_pycharmm_state()

# %%
from pycharmm import generate, ic, read, settings
from mmml.interfaces.pycharmmInterface.protein_charmm_build import protein_toppar_paths

toppar = protein_toppar_paths()
settings.set_verbosity(5)
read.rtf(str(toppar.rtf))
read.prm(str(toppar.prm))
read.sequence_string("ALA ALA ALA")  # four-char segment names in real workflows
generate.new_segment(
    seg_name="TRP1",
    first_patch="ACE",
    last_patch="CT3",
    setup_ic=True,
)
ic.prm_fill(replace_all=True)
ic.build()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from pycharmm import generate, ic, read, settings
#       2 from mmml.interfaces.pycharmmInterface.protein_charmm_build import protein_toppar_paths
#       3
#       4 toppar = protein_toppar_paths()
#
# File ~/mmml/pycharmm/__init__.py:17
#       1 # pycharmm: molecular dynamics in python with CHARMM
#       2 # Copyright (C) 2018 Josh Buckner
#       3
#    (...)     14 # You should have received a copy of the GNU General Public License
#      15 # along with this program.  If not, see <http://www.gnu.org/licenses/>.
# ---> 17 from .atom_info import get_atom_table
#      18 from .charmm_file import CharmmFile
#      19 from .coor import Coordinates
#
# File ~/mmml/pycharmm/atom_info.py:24
#      22 import pandas
#      23 import pycharmm
# ---> 24 import pycharmm.coor as coor
#      25 import pycharmm.param as param
#      26 import pycharmm.psf as psf
#
# File ~/mmml/pycharmm/coor.py:31
#      28 import numpy as np
#      30 import pycharmm
# ---> 31 import pycharmm.lib as lib
#      33 def get_natom():
#      34     """Returns the number of atoms currently in the simulation
#      35
#      36     Returns
#    (...)     39         number of atoms currently in the simulation
#      40     """
#
# File ~/mmml/pycharmm/lib.py:69
#      64         self.lib.del_charmm()  # initiates 'normal stop'
#      65         # does not work
#      66         # self.lib.dlclose(self.lib)
# ---> 69 charmm_lib = CharmmLib(os.environ.get('CHARMM_LIB_DIR', ''))
#      70 charmm = charmm_lib.lib
#
# File ~/mmml/pycharmm/lib.py:48, in CharmmLib.__init__(self, charmm_lib_dir)
#      45     self.charmm_lib_name += '.dll'
#      47 self.lib = None
# ---> 48 self.init_charmm()
#      50 self.dlclose = ctypes.CDLL(None).dlclose  # does not work
#      51 self.dlclose.argtypes = [ctypes.c_void_p]
#
# File ~/mmml/pycharmm/lib.py:58, in CharmmLib.init_charmm(self)
#      57 def init_charmm(self):
# ---> 58     self.lib = ctypes.CDLL(self.charmm_lib_name)
#      59     self.lib.init_charmm()
#
# File ~/.local/share/uv/python/cpython-3.13.11-linux-x86_64-gnu/lib/python3.13/ctypes/__init__.py:361, in CDLL.__init__(self, name, mode, handle, use_errno, use_last_error, winmode)
#     358 if name:
#     359     name = _os.fspath(name)
# --> 361 self._handle = self._load_library(name, mode, handle, winmode)
#
# File ~/.local/share/uv/python/cpython-3.13.11-linux-x86_64-gnu/lib/python3.13/ctypes/__init__.py:401, in CDLL._load_library(self, name, mode, handle, winmode)
#     399         mode |= _os.RTLD_MEMBER | _os.RTLD_NOW
#     400 self._name = name
# --> 401 return _dlopen(name, mode)
#
# OSError: libcharmm.so: cannot open shared object file: No such file or directory
