# %%
import os
os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"] = ".99"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %load_ext autoreload
# %autoreload 2

import pandas as pd
import dcmnet
import sys

sys.path.append("/home/boittier/jaxeq/dcmnet")
print(sys.path)
from dcmnet.models import DCM1, DCM2, DCM3, DCM4, dcm1_params, dcm2_params, dcm3_params, dcm4_params
from dcmnet.modules import MessagePassingModel
from dcmnet.data import prepare_datasets

import numpy as np

def atom_centered_dipole(dcm, com, q):
    dipole_out = np.zeros(3)
    for i, _ in enumerate(dcm):
        dipole_out += q[i] * (_ - com)
    print(dipole_out*2.5417464519)
    return np.linalg.norm(dipole_out)* 4.80320

import jax
import jax.numpy as jnp
import pickle
from tensorboardX import SummaryWriter
import time
from dcmnet.utils import safe_mkdir
from dcmnet.training import train_model
from dcmnet.training_dipole import train_model_dipo
from pathlib import Path
from dcmnet.data import prepare_batches, prepare_datasets
from dcmnet.utils import apply_model
from dcmnet.plotting import evaluate_dc, plot_esp, plot_model
import optax

import jax
devices = jax.local_devices()
print(devices)
print(jax.default_backend())
print(jax.devices())
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ['/pchem-data/meuwly/boittier/home/miniforge3/envs/jaxe3xcuda11p39/lib/python39.zip', '/pchem-data/meuwly/boittier/home/miniforge3/envs/jaxe3xcuda11p39/lib/python3.9', '/pchem-data/meuwly/boittier/home/miniforge3/envs/jaxe3xcuda11p39/lib/python3.9/lib-dynload', '', '/pchem-data/meuwly/boittier/home/miniforge3/envs/jaxe3xcuda11p39/lib/python3.9/site-packages', '/pchem-data/meuwly/boittier/home/jaxeq', '/home/boittier/jaxeq/dcmnet', '/home/boittier/jaxeq/dcmnet']
# [CpuDevice(id=0)]
# cpu
# [CpuDevice(id=0)]

# %%
class Args:
    def __init__(self):
        self.data_dir = "/pchem-data/meuwly/boittier/home/jaxeq/"
        self.esp_w = 1000
        self.n_mp = 2
        self.learning_rate = 0.0001
        self.num_epochs = 2
        self.restart = None
        self.data = "qm9-esp40000-0.npz"
        self.num_epics = 1
        self.random_seed = 0
        self.n_dcm = 2

# %%
args = Args()

# %%
NATOMS = 60
data_key, train_key = jax.random.split(jax.random.PRNGKey(args.random_seed), 2)

# Model hyperparameters.
features = 16
max_degree = 2
num_iterations = args.n_mp
num_basis_functions = 8
cutoff = 4.0

n_dcm = 3
# Training hyperparameters.
learning_rate = args.learning_rate
batch_size = 1
esp_w = args.esp_w
restart_params = args.restart
if restart_params is not None:
    restart_params = pd.read_pickle(restart_params)
params = restart_params
data_file = Path(args.data_dir) / args.data

# train_data, valid_data = prepare_datasets(
#     data_key, args.ntrain, args.nvalid, filename=data_file
# )

train_data, valid_data = prepare_datasets(
    data_key,
    # 120000 - 6908,
    # 40000 - 6907,
    # 6907,
    int(80000*0.5),
    int(80000*0.1),
    # 1,
    # 10,
    # 1,
    # 1,
    [
        Path(args.data_dir) / "data/qm9-esp-dip-40000-0.npz", 
        Path(args.data_dir) / "data/qm9-esp-dip-40000-1.npz", 
        Path(args.data_dir) / "data/qm9-esp-dip-40000-2.npz", 
        # Path(args.data_dir) / "data/qm9-esp-dip-6907-3.npz", 
        # Path(args.data_dir) / "data/qm9-esp-dip-1000-0.npz", 
        # Path(args.data_dir) / "data/qm9-esp-dip-1000-1.npz", 
        # Path(args.data_dir) / "data/qm9-esp-dip-1000-2.npz", 
     # Path(args.data_dir) / "data/qm9-esp40000-1.npz", 
     # Path(args.data_dir) / "data/qm9-esp40000-2.npz",
       # Path(args.data_dir) / "data/qm9-esp6907-3.npz" 
    ]
)
# Out:
# R (40000, 60, 3)
# Z (40000, 60)
# N (40000,)
# D (40000,)
# com (40000, 3)
# Dxyz (40000, 3)
# mono (40000, 60, 1)
# esp (40000, 3200)
# id (40000,)
# n_grid (40000,)
# vdw_surface (40000, 3200, 3)
# R (40000, 60, 3)
# Z (40000, 60)
# N (40000,)
# D (40000,)
# com (40000, 3)
# Dxyz (40000, 3)
# mono (40000, 60, 1)
# esp (40000, 3200)
# id (40000,)
# n_grid (40000,)
# vdw_surface (40000, 3200, 3)
# R (40000, 60, 3)
# Z (40000, 60)
# N (40000,)
# D (40000,)
# com (40000, 3)
# Dxyz (40000, 3)
# mono (40000, 60, 1)
# esp (40000, 3200)
# id (40000,)
# n_grid (40000,)
# vdw_surface (40000, 3200, 3)
# 120000

# %%
# Create and train model.
message_passing_model = MessagePassingModel(
    features=features,
    max_degree=max_degree,
    num_iterations=num_iterations,
    num_basis_functions=num_basis_functions,
    cutoff=cutoff,
    n_dcm=n_dcm,
)

# %%
num_epochs = args.num_epochs

# %%
# PARAMS = pd.read_pickle(
#     "/pchem-data/meuwly/boittier/home/jaxeq/runs6/"\
#     "20240828-152758dcm-2-espw-1000-qm9-esp40000-0.npz-re-False/best_100_params.pkl")

# PARAMS = pd.read_pickle(
#     "/pchem-data/meuwly/boittier/home/jaxeq/runs7/"\
#     # "20240829-145230dcm-2-espw-1000-qm9-esp40000-0.npz-re-False/best_1000_params.pkl")
# "20240829-225716dcm-2-espw-1000-qm9-esp40000-0.npz-re-False/best_1000_params.pkl")
# # 
# PARAMS = pd.read_pickle(
#     "/pchem-data/meuwly/boittier/home/jaxeq/runs7/"\
#     # "20240830-113204dcm-2-espw-1000-qm9-esp40000-0.npz-re-False/best_1000_params.pkl")
# # 
#     "20240830-122426dcm-2-espw-1000-qm9-esp40000-0.npz-re-False/best_1000_params.pkl")

# params = "/pchem-data/meuwly/boittier/home/jaxeq/all_runs/runs8/"\
# "20240920-122013dcm-2-espw-1000-qm9-esp40000-0.npz-re-False/best_100000_params.pkl"
# PARAMS = pd.read_pickle(params)

params = "/pchem-data/meuwly/boittier/home/jaxeq/all_runs/runs7/20240830-165613dcm-3-espw-1000-qm9-esp40000-0.npz-re-False/best_1000_params.pkl"
PARAMS = pd.read_pickle(params)

# %%
# make checkpoint directory
safe_mkdir(f"/pchem-data/meuwly/boittier/jaxeq/checkpoints2/dcm{n_dcm}-{esp_w}")
isRestart = args.restart is not None
# Set up TensorBoard writer
log_dir = (
    "/pchem-data/meuwly/boittier/home/jaxeq/all_runs/runs8/"
    + time.strftime("%Y%m%d-%H%M%S")
    + f"dcm-{n_dcm}-espw-{esp_w}-{args.data}-re-{isRestart}"
)
writer = SummaryWriter(log_dir)
print(log_dir)
with open(log_dir + "/manifest.txt", "w") as f:
    f.write(str(message_passing_model))
    for k, v in vars(args).items():
        f.write(f"\n{k} = {v}")

for epic in range(1, args.num_epics + 1):
    print(f"epic {epic}")
    params, val = train_model_dipo(
        key=train_key,
        model=message_passing_model,
        train_data=train_data,
        valid_data=valid_data,
        num_epochs=100,
        learning_rate=learning_rate/400,
        batch_size=batch_size,
        writer=writer,
        restart_params=PARAMS,
        esp_w=100000,
        ndcm=3,
    )

    # open a file, where you want to store the data
    with open(
        f"/home/boittier/jaxeq/checkpoints2/dcm{n_dcm}-{esp_w}/{epic}-{val}-esp_params.pkl",
        "wb",
    ) as file:
        pickle.dump(params, file)
# Out:
# /pchem-data/meuwly/boittier/home/jaxeq/all_runs/runs8/20240920-184256dcm-3-espw-1000-qm9-esp40000-0.npz-re-False
# epic 1
# Preparing batches
# ..................
# epoch:   1      train:   valid:
#     loss [a.u.]              2.091e-01  2.020e-01
# epoch:   2      train:   valid:
#     loss [a.u.]              1.989e-01  1.962e-01
# epoch:   3      train:   valid:
#     loss [a.u.]              1.943e-01  1.924e-01
# epoch:   4      train:   valid:
#     loss [a.u.]              1.910e-01  1.896e-01
# epoch:   5      train:   valid:
#     loss [a.u.]              1.886e-01  1.874e-01
# epoch:   6      train:   valid:
#     loss [a.u.]              1.866e-01  1.856e-01
# epoch:   7      train:   valid:
#     loss [a.u.]              1.849e-01  1.841e-01
# epoch:   8      train:   valid:
#     loss [a.u.]              1.836e-01  1.828e-01
# epoch:   9      train:   valid:
#     loss [a.u.]              1.824e-01  1.817e-01
# epoch:  10      train:   valid:
#     loss [a.u.]              1.814e-01  1.808e-01
# epoch:  11      train:   valid:
#     loss [a.u.]              1.805e-01  1.800e-01
# epoch:  12      train:   valid:
#     loss [a.u.]              1.797e-01  1.792e-01
# epoch:  13      train:   valid:
#     loss [a.u.]              1.790e-01  1.786e-01
# epoch:  14      train:   valid:
#     loss [a.u.]              1.784e-01  1.779e-01
# epoch:  15      train:   valid:
#     loss [a.u.]              1.778e-01  1.774e-01
# epoch:  16      train:   valid:
#     loss [a.u.]              1.773e-01  1.769e-01
# epoch:  17      train:   valid:
#     loss [a.u.]              1.768e-01  1.764e-01
# epoch:  18      train:   valid:
#     loss [a.u.]              1.764e-01  1.760e-01
# epoch:  19      train:   valid:
#     loss [a.u.]              1.760e-01  1.756e-01
# epoch:  20      train:   valid:
#     loss [a.u.]              1.756e-01  1.752e-01
# epoch:  21      train:   valid:
#     loss [a.u.]              1.752e-01  1.749e-01
# epoch:  22      train:   valid:
#     loss [a.u.]              1.749e-01  1.746e-01
# epoch:  23      train:   valid:
#     loss [a.u.]              1.746e-01  1.742e-01
# epoch:  24      train:   valid:
#     loss [a.u.]              1.743e-01  1.740e-01
# epoch:  25      train:   valid:
#     loss [a.u.]              1.740e-01  1.737e-01
# epoch:  26      train:   valid:
#     loss [a.u.]              1.737e-01  1.734e-01
# epoch:  27      train:   valid:
#     loss [a.u.]              1.734e-01  1.731e-01
# epoch:  28      train:   valid:
#     loss [a.u.]              1.732e-01  1.729e-01
# epoch:  29      train:   valid:
#     loss [a.u.]              1.730e-01  1.727e-01
# epoch:  30      train:   valid:
#     loss [a.u.]              1.727e-01  1.724e-01
# epoch:  31      train:   valid:
#     loss [a.u.]              1.725e-01  1.722e-01
# epoch:  32      train:   valid:
#     loss [a.u.]              1.723e-01  1.720e-01
# epoch:  33      train:   valid:
#     loss [a.u.]              1.721e-01  1.718e-01
# epoch:  34      train:   valid:
#     loss [a.u.]              1.719e-01  1.716e-01
# epoch:  35      train:   valid:
#     loss [a.u.]              1.717e-01  1.714e-01
# epoch:  36      train:   valid:
#     loss [a.u.]              1.715e-01  1.712e-01
# epoch:  37      train:   valid:
#     loss [a.u.]              1.713e-01  1.711e-01
# epoch:  38      train:   valid:
#     loss [a.u.]              1.712e-01  1.709e-01
# epoch:  39      train:   valid:
#     loss [a.u.]              1.710e-01  1.708e-01
# epoch:  40      train:   valid:
#     loss [a.u.]              1.708e-01  1.706e-01
# epoch:  41      train:   valid:
#     loss [a.u.]              1.707e-01  1.704e-01
# epoch:  42      train:   valid:
#     loss [a.u.]              1.705e-01  1.702e-01
# epoch:  43      train:   valid:
#     loss [a.u.]              1.703e-01  1.701e-01
# epoch:  44      train:   valid:
#     loss [a.u.]              1.702e-01  1.699e-01
# epoch:  45      train:   valid:
#     loss [a.u.]              1.701e-01  1.698e-01
# epoch:  46      train:   valid:
#     loss [a.u.]              1.699e-01  1.697e-01
# epoch:  47      train:   valid:
#     loss [a.u.]              1.698e-01  1.695e-01
# epoch:  48      train:   valid:
#     loss [a.u.]              1.696e-01  1.694e-01
# epoch:  49      train:   valid:
#     loss [a.u.]              1.695e-01  1.692e-01
# epoch:  50      train:   valid:
#     loss [a.u.]              1.694e-01  1.691e-01
# epoch:  51      train:   valid:
#     loss [a.u.]              1.692e-01  1.690e-01
# epoch:  52      train:   valid:
#     loss [a.u.]              1.691e-01  1.689e-01
# epoch:  53      train:   valid:
#     loss [a.u.]              1.690e-01  1.687e-01
# epoch:  54      train:   valid:
#     loss [a.u.]              1.689e-01  1.686e-01
# epoch:  55      train:   valid:
#     loss [a.u.]              1.688e-01  1.685e-01
# epoch:  56      train:   valid:
#     loss [a.u.]              1.686e-01  1.684e-01
# epoch:  57      train:   valid:
#     loss [a.u.]              1.685e-01  1.683e-01
# epoch:  58      train:   valid:
#     loss [a.u.]              1.684e-01  1.682e-01
# epoch:  59      train:   valid:
#     loss [a.u.]              1.683e-01  1.680e-01
# epoch:  60      train:   valid:
#     loss [a.u.]              1.682e-01  1.679e-01
# epoch:  61      train:   valid:
#     loss [a.u.]              1.681e-01  1.678e-01
# epoch:  62      train:   valid:
#     loss [a.u.]              1.680e-01  1.677e-01
# epoch:  63      train:   valid:
#     loss [a.u.]              1.679e-01  1.676e-01
# epoch:  64      train:   valid:
#     loss [a.u.]              1.678e-01  1.675e-01
# epoch:  65      train:   valid:
#     loss [a.u.]              1.677e-01  1.674e-01
# epoch:  66      train:   valid:
#     loss [a.u.]              1.676e-01  1.673e-01
# epoch:  67      train:   valid:
#     loss [a.u.]              1.675e-01  1.672e-01
# epoch:  68      train:   valid:
#     loss [a.u.]              1.674e-01  1.671e-01
# epoch:  69      train:   valid:
#     loss [a.u.]              1.673e-01  1.670e-01
# epoch:  70      train:   valid:
#     loss [a.u.]              1.672e-01  1.669e-01
# epoch:  71      train:   valid:
#     loss [a.u.]              1.671e-01  1.668e-01
# epoch:  72      train:   valid:
#     loss [a.u.]              1.670e-01  1.667e-01
# epoch:  73      train:   valid:
#     loss [a.u.]              1.669e-01  1.666e-01
# epoch:  74      train:   valid:
#     loss [a.u.]              1.668e-01  1.666e-01
# epoch:  75      train:   valid:
#     loss [a.u.]              1.667e-01  1.665e-01
# epoch:  76      train:   valid:
#     loss [a.u.]              1.666e-01  1.664e-01
# epoch:  77      train:   valid:
#     loss [a.u.]              1.665e-01  1.663e-01
# epoch:  78      train:   valid:
#     loss [a.u.]              1.664e-01  1.662e-01
# epoch:  79      train:   valid:
#     loss [a.u.]              1.664e-01  1.661e-01
# epoch:  80      train:   valid:
#     loss [a.u.]              1.663e-01  1.660e-01
# epoch:  81      train:   valid:
#     loss [a.u.]              1.662e-01  1.659e-01
# epoch:  82      train:   valid:
#     loss [a.u.]              1.661e-01  1.659e-01
# epoch:  83      train:   valid:
#     loss [a.u.]              1.660e-01  1.658e-01
# epoch:  84      train:   valid:
#     loss [a.u.]              1.660e-01  1.657e-01
# epoch:  85      train:   valid:
#     loss [a.u.]              1.659e-01  1.656e-01
# epoch:  86      train:   valid:
#     loss [a.u.]              1.658e-01  1.655e-01
# epoch:  87      train:   valid:
#     loss [a.u.]              1.657e-01  1.655e-01
# epoch:  88      train:   valid:
#     loss [a.u.]              1.656e-01  1.654e-01
# epoch:  89      train:   valid:
#     loss [a.u.]              1.656e-01  1.653e-01
# epoch:  90      train:   valid:
#     loss [a.u.]              1.655e-01  1.652e-01
# epoch:  91      train:   valid:
#     loss [a.u.]              1.654e-01  1.651e-01
# epoch:  92      train:   valid:
#     loss [a.u.]              1.653e-01  1.651e-01
# epoch:  93      train:   valid:
#     loss [a.u.]              1.653e-01  1.650e-01
# epoch:  94      train:   valid:
#     loss [a.u.]              1.652e-01  1.649e-01
# epoch:  95      train:   valid:
#     loss [a.u.]              1.651e-01  1.648e-01
# epoch:  96      train:   valid:
#     loss [a.u.]              1.650e-01  1.648e-01
# epoch:  97      train:   valid:
#     loss [a.u.]              1.650e-01  1.647e-01
# epoch:  98      train:   valid:
#     loss [a.u.]              1.649e-01  1.646e-01
# epoch:  99      train:   valid:
#     loss [a.u.]              1.648e-01  1.646e-01
# epoch:  100      train:   valid:
#     loss [a.u.]              1.647e-01  1.645e-01
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 34
#      19 params, val = train_model_dipo(
#      20     key=train_key,
#      21     model=message_passing_model,
#    (...)
#      30     ndcm=3,
#      31 )
#      33 # open a file, where you want to store the data
# ---> 34 with open(
#      35     f"/home/boittier/jaxeq/checkpoints2/dcm{n_dcm}-{esp_w}/{epic}-{val}-esp_params.pkl",
#      36     "wb",
#      37 ) as file:
#      38     pickle.dump(params, file)
#
# File ~/miniforge3/envs/jaxe3xcuda11p39/lib/python3.9/site-packages/IPython/core/interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/boittier/jaxeq/checkpoints2/dcm3-1000/1-0.16449818015098572-esp_params.pkl'

# %%
# PARAMS = pd.read_pickle(
#     "/pchem-data/meuwly/boittier/home/jaxeq/runs7/"\
#     "20240829-145230dcm-2-espw-1000-qm9-esp40000-0.npz-re-False/best_1000_params.pkl")

# %%
valid_batches = prepare_batches(data_key, valid_data, batch_size, include_id=True)

# %%
# valid_batches = prepare_batches(data_key, train_data, batch_size, include_id=True)

# %%
batch = valid_batches[-1]

# %%
mono_test = batch["mono"]
positions_test = batch["R"]
D_test = batch["D"][0]
com_test = batch["com"][0]

# %%
pred_D = atom_centered_dipole(positions_test, com_test, mono_test)
print(batch["Dxyz"][0])
pred_D, D_test, abs(pred_D - D_test)
# Out:
# [-0.09370929  0.3760829  -0.63019388]
# [-0.0463749  0.1506537 -0.4533559]
# (np.float64(1.398094732642288),
#  np.float64(1.219982124315413),
#  np.float64(0.17811260832687492))

# %%
jnp.mean(optax.l2_loss(pred_D, D_test))
# Out:
# Array(0.01586205, dtype=float32)

# %%
mono, dipo = apply_model(message_passing_model, params, batch, batch_size)
error, esp, keys, _ = evaluate_dc(batch, dipo, mono, batch_size, message_passing_model.n_dcm,
                                       plot="test",
                                       id=True,
                              )

# %%
dipo.shape
# Out:
# (180, 3)

# %%
pred_D = atom_centered_dipole(dipo, com_test, mono.reshape(message_passing_model.n_dcm * 60, 1))
print(batch["Dxyz"][0])
pred_D, D_test, abs(pred_D - D_test)
# Out:
# [-0.0487706   0.33614647 -0.65795135]
# [-0.0463749  0.1506537 -0.4533559]
# (np.float32(1.3992549),
#  np.float64(1.219982124315413),
#  np.float64(0.17927279378303673))

# %%
jnp.mean(optax.l2_loss(pred_D, D_test))
# Out:
# Array(0.01606937, dtype=float32)

# %%
# def pred_dipole(dcm, com, q):
#     dipole_out = jnp.zeros(3)
#     for i, _ in enumerate(dcm):
#         dipole_out += q[i] * (_ - com)
#     return jnp.linalg.norm(dipole_out)* 4.80320
    
d = jnp.moveaxis(dipo, -1, -2).reshape(batch_size, NATOMS * message_passing_model.n_dcm, 3)
m = mono.reshape(batch_size, NATOMS * message_passing_model.n_dcm)

molecular_dipole = atom_centered_dipole(d[0], com_test, m[0])
molecular_dipole, D_test, abs(molecular_dipole - D_test), jnp.mean(optax.l2_loss(molecular_dipole, D_test))

# %%
mono, dipo = apply_model(message_passing_model, dcm2_params, batch, batch_size)
non_zero = jnp.nonzero(batch["atomic_numbers"])
error, esp, keys, _ = evaluate_dc(batch, dipo, mono, batch_size, message_passing_model.n_dcm,
                                       plot="Test",
                                       id=True,
                              )

# %%
d = jnp.moveaxis(dipo, -1, -2).reshape(batch_size, NATOMS * message_passing_model.n_dcm, 3)
m = mono.reshape(batch_size, NATOMS * message_passing_model.n_dcm)
molecular_dipole = pred_dipole(d[0], com_test, m[0])
molecular_dipole, D_test, abs(molecular_dipole - D_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 3
#       1 d = jnp.moveaxis(dipo, -1, -2).reshape(batch_size, NATOMS * message_passing_model.n_dcm, 3)
#       2 m = mono.reshape(batch_size, NATOMS * message_passing_model.n_dcm)
# ----> 3 molecular_dipole = pred_dipole(d[0], com_test, m[0])
#       4 molecular_dipole, D_test, abs(molecular_dipole - D_test)
#
# NameError: name 'pred_dipole' is not defined

# %%
mono, dipo = apply_model(message_passing_model, PARAMS, batch, batch_size)
non_zero = jnp.nonzero(batch["atomic_numbers"])
error, esp, keys, _ = evaluate_dc(batch, dipo, mono, batch_size, message_passing_model.n_dcm,
                                       plot="Test",
                                       id=True,
                              )

# %%
d = jnp.moveaxis(dipo, -1, -2).reshape(batch_size, NATOMS * message_passing_model.n_dcm, 3)
m = mono.reshape(batch_size, NATOMS * message_passing_model.n_dcm)
molecular_dipole = pred_dipole(d[0], com_test, m[0])
molecular_dipole, D_test, abs(molecular_dipole - D_test)
