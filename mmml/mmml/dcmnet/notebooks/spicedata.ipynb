# %%
from molflux.datasets import load_dataset

dataset = load_dataset("spice", "rdkit")
# Out:
# Repo card metadata block was not found. Setting CardData to empty.
# ...
# Generating train split: 0 examples [00:00, ? examples/s]
# Loading dataset shards:   0%|          | 0/68 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 from molflux.datasets import load_dataset
# ----> 3 dataset = load_dataset("spice", "rdkit")
#
# File ~/psi4conda/envs/jaxe3xcuda11py39/lib/python3.9/site-packages/molflux/datasets/load.py:179, in load_dataset(name, config_name, split, streaming, **kwargs)
#     172 # Do not pass through unhandled deprecation warnings from dependencies of hf datasets themselves
#     173 warnings.filterwarnings(
#     174     "ignore",
#     175     message="The .* keyword in pd.read_csv is deprecated and will be removed in a future version",
#     176     category=FutureWarning,
#     177     module="datasets[.*]",
#     178 )
# ...
