# %% [markdown]
# # MD17: Ethanol (force field construction)
# This tutorial demonstrates how to use E3x to construct a machine-learned force field. For this example, we use the MD17 dataset for ethanol. The code is written to be easy to adapt to datasets that contain multiple molecules of different size.

# %% [markdown]
# First, all necessary packages are imported.

# %%
import functools
import os
import urllib.request
import e3x
import flax.linen as nn
import jax
import jax.numpy as jnp
import numpy as np
import optax

# Disable future warnings.
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# jax_ex

# %%
# import jax
jax.default_backend()
jax.devices()
# Out:
# [CpuDevice(id=0)]

# %%
data_key, train_key = jax.random.split(jax.random.PRNGKey(0), 2)

# %% [markdown]
# Next, we download the MD17 dataset for ethanol.

# %%
# Download the dataset.
filename = "md17_ethanol.npz"
if not os.path.exists(filename):
  print(f"Downloading {filename} (this may take a while)...")
  urllib.request.urlretrieve(f"http://www.quantum-machine.org/gdml/data/npz/{filename}", filename)

# %% [markdown]
# Now we write a small helper function to prepare train and validation datasets. Apart from choosing subsets of the full dataset and converting the data to a different format, this function also subtracts the mean energy of the training set from all data points. This is a useful numerical trick: The energy of a molecule is often a very large number (around $-97 000$ kcal/mol for ethanol), but the relative energy between different conformations of the same molecule is usually much smaller (a few kcal/mol for ethanol). Since models are typically trained with single precision floats for efficiency, the large energy offset wastes precious numerical precision. For this reason, large offsets should be subtracted frow the raw data (typically stored in double precision) *before* converting to single precision. Note that subtracting arbitrary constants from the energy does not change physics (of course, the constant can also just be added back to the model predictions after training).

# %%
def prepare_datasets(key, num_train, num_valid, filename="240124_combined_water.npz"):
  # Load the dataset.
  dataset = np.load(filename)
    
  for k,v in dataset.items():
      print(k, v.shape)

  # Make sure that the dataset contains enough entries.
  num_data = len(dataset['E'])
  print(num_data)
  num_draw = num_train + num_valid
  if num_draw > num_data:
    raise RuntimeError(
      f'datasets only contains {num_data} points, requested num_train={num_train}, num_valid={num_valid}')

  # Randomly draw train and validation sets from dataset.
  choice = np.asarray(jax.random.choice(key, num_data, shape=(num_draw,), replace=False))
  train_choice = choice[:num_train]
  valid_choice = choice[num_train:]

  # atomic_numbers = jnp.tile(dataset['z'], num_data).reshape((num_data, len(dataset["z"])))
  atomic_numbers = dataset['z']
  print("atomic_numbers", atomic_numbers.shape)
    
  # Determine mean energy of the training set.
  # mean_energy = np.mean(dataset['E'][train_choice])  # ~ -97000
  mean_energy = 0

  # Collect and return train and validation sets.
  train_data = dict(
    # energy=jnp.asarray(dataset['E'][train_choice, 0] - mean_energy),
    energy=jnp.asarray(dataset['E'][train_choice] - mean_energy),
      
    forces=jnp.asarray(dataset['F'][train_choice]),
    # atomic_numbers=jnp.asarray(dataset['z']),
    atomic_numbers=jnp.asarray(atomic_numbers[train_choice]),
    positions=jnp.asarray(dataset['R'][train_choice]),
  )
  valid_data = dict(
    # energy=jnp.asarray(dataset['E'][valid_choice, 0] - mean_energy),
    energy=jnp.asarray(dataset['E'][valid_choice] - mean_energy),
      
    forces=jnp.asarray(dataset['F'][valid_choice]),
    # atomic_numbers=jnp.asarray(dataset['z']),
    atomic_numbers=jnp.asarray(atomic_numbers[valid_choice]),
    positions=jnp.asarray(dataset['R'][valid_choice]),
  )


  for k,v in train_data.items():
      print(k, v.shape)

  for k,v in valid_data.items():
      print(k, v.shape)
      
  return train_data, valid_data, mean_energy

# %% [markdown]
# Next, we define a very simple message-passing neural network.
#
# Let's first describe the model inputs and outputs: Our model takes `atomic_numbers` of shape `(num_atoms,)` (encoding the atom types), `positions` of shape `(num_atoms, 3)`, and index lists `dst_idx` (destination index) and `src_idx` (source index), both of shape `(num_pairs,)`, as inputs. The `dst_idx` and `src_idx` index lists specify "which atoms talk with each other" during a message-pass. For example, for a molecule with three atoms, these index lists could be `dst_idx = [0, 0, 1, 1, 2, 2]` and `src_idx = [1, 2, 0, 2, 0, 1]`. This would mean that the "destination atom" at index 0 receives messages from the "source atoms" at indices 1 and 2, and so on. This input format allows the model to handle batches of molecules with different numbers of atoms *without needing any padding* (in this example, all molecules are ethanol, so this is not necessary, but it's useful in general for more complicated tasks). We simply concatenate the `atomic_numbers` and `positions` of all molecules in the batch (as if they were one big molecule) and specify the index lists such that atoms in different molecules of the batch do not "talk to each other". The only additional information we need is a structure `batch_segments` that tells the model which atoms belong to which molecule in the batch and the total `batch_size`. For example, a batch consisting of a H$_2$O and a N$_2$ molecule could be specified with `atomic_numbers = [1, 1, 8, 7, 7]`, `dst_idx = [0, 0, 1, 1, 2, 2, 3, 4]`, `src_idx = [1, 2, 0, 2, 0, 1, 4, 3]`, `batch_segments = [0, 0, 0, 1, 1]` (meaning the first three atoms belong to molecule `0`, the last two to molecule `1`), and `batch_size = 2`. The outputs of our model are the `energy` of shape `(batch_size,)` of every molecule in the batch and the `forces` of shape `(num_atoms, 3)` acting on each atom.
#
# Since `forces` are the negative gradient of the `energy` with respect to the atomic `positions`, the model only needs to predict `energy`, as `forces` can be derived with automatic differentiation. This has the additional advantage that the forces will be conservative, i.e. they will respect the physical principle of energy conservation. The energy prediction comprises the following steps:
#
# 1. Calculate the displacement vectors $\vec{r}_{ij}=\vec{r}_{j}-\vec{r}_{i}$, where $\vec{r}_{i}$ and $\vec{r}_{j}$ are the positions of atoms $i$ (destination) and $j$ (source), for all pairs $i,j$ specified by the index lists.
#
# 2. Expand the displacement vectors in radial-spherical basis functions to featurize them. Note that the basis functions use a cutoff, so that they go to zero beyond a certain distance.
#
# 3. Embed the atoms in feature space by assigning them to learnable embeddings (one for each element).
#
# 4. Perform `num_iterations` feature refinements. Each iteration performs a message-pass and combines the message with the current features of each atom. These intermediate features are passed through an atom-wise two-layer MLP and added to the original features (residual connection).
#
# 5. Predict atomic energy contributions by performing linear regression on the final (scalar) features of each atom. Each atom type/element has its own bias term.
#
# 6. Sum the atomic energy contributions within each batch segment to obtain the energy for every molecule in the batch.

# %%
class MessagePassingModel(nn.Module):
  features: int = 32
  max_degree: int = 2
  num_iterations: int = 3
  num_basis_functions: int = 8
  cutoff: float = 5.0
  max_atomic_number: int = 118  # This is overkill for most applications.


  def energy(self, atomic_numbers, positions, dst_idx, src_idx, batch_segments, batch_size):
    # 1. Calculate displacement vectors.
    positions_dst = e3x.ops.gather_dst(positions, dst_idx=dst_idx)
    positions_src = e3x.ops.gather_src(positions, src_idx=src_idx)
    displacements = positions_src - positions_dst  # Shape (num_pairs, 3).

    # 2. Expand displacement vectors in basis functions.
    basis = e3x.nn.basis(  # Shape (num_pairs, 1, (max_degree+1)**2, num_basis_functions).
      displacements,
      num=self.num_basis_functions,
      max_degree=self.max_degree,
      radial_fn=e3x.nn.reciprocal_bernstein,
      cutoff_fn=functools.partial(e3x.nn.smooth_cutoff, cutoff=self.cutoff)
    )

    # 3. Embed atomic numbers in feature space, x has shape (num_atoms, 1, 1, features).
    x = e3x.nn.Embed(num_embeddings=self.max_atomic_number+1, features=self.features)(atomic_numbers)

    # 4. Perform iterations (message-passing + atom-wise refinement).
    for i in range(self.num_iterations):
      # Message-pass.
      if i == self.num_iterations-1:  # Final iteration.
        # Since we will only use scalar features after the final message-pass, we do not want to produce non-scalar
        # features for efficiency reasons.
        y = e3x.nn.MessagePass(max_degree=0, include_pseudotensors=False)(x, basis, dst_idx=dst_idx, src_idx=src_idx)
        # After the final message pass, we can safely throw away all non-scalar features.
        x = e3x.nn.change_max_degree_or_type(x, max_degree=0, include_pseudotensors=False)
      else:
        # In intermediate iterations, the message-pass should consider all possible coupling paths.
        y = e3x.nn.MessagePass()(x, basis, dst_idx=dst_idx, src_idx=src_idx)
      y = e3x.nn.add(x, y)

      # Atom-wise refinement MLP.
      y = e3x.nn.Dense(self.features)(y)
      y = e3x.nn.silu(y)
      y = e3x.nn.Dense(self.features, kernel_init=jax.nn.initializers.zeros)(y)

      # Residual connection.
      x = e3x.nn.add(x, y)

    # 5. Predict atomic energies with an ordinary dense layer.
    element_bias = self.param('element_bias', lambda rng, shape: jnp.zeros(shape), (self.max_atomic_number+1))
    atomic_energies = nn.Dense(1, use_bias=False, kernel_init=jax.nn.initializers.zeros)(x)  # (..., Natoms, 1, 1, 1)
    atomic_energies = jnp.squeeze(atomic_energies, axis=(-1, -2, -3))  # Squeeze last 3 dimensions.
    atomic_energies += element_bias[atomic_numbers]

    # 6. Sum atomic energies to obtain the total energy.
    energy = jax.ops.segment_sum(atomic_energies, segment_ids=batch_segments, num_segments=batch_size)

    # To be able to efficiently compute forces, our model should return a single output (instead of one for each
    # molecule in the batch). Fortunately, since all atomic contributions only influence the energy in their own
    # batch segment, we can simply sum the energy of all molecules in the batch to obtain a single proxy output
    # to differentiate.
    return -jnp.sum(energy), energy  # Forces are the negative gradient, hence the minus sign.


  @nn.compact
  def __call__(self, atomic_numbers, positions, dst_idx, src_idx, batch_segments=None, batch_size=None):
    if batch_segments is None:
      batch_segments = jnp.zeros_like(atomic_numbers)
      batch_size = 1

    # Since we want to also predict forces, i.e. the gradient of the energy w.r.t. positions (argument 1), we use
    # jax.value_and_grad to create a function for predicting both energy and forces for us.
    energy_and_forces = jax.value_and_grad(self.energy, argnums=1, has_aux=True)
    (_, energy), forces = energy_and_forces(atomic_numbers, positions, dst_idx, src_idx, batch_segments, batch_size)

    return energy, forces

# %% [markdown]
# With our model in place, we now write a function to prepare a batch of molecules in the format described above. For this simple example, the source and destination index lists include all $N(N-1)$ pairwise combinations of $N$ atoms (without self-interactions). E3x contains helper functions, such as `sparse_pairwise_indices`, to construct such $O(N^2)$ index lists. This is fine for a small molecule like ethanol, but we can do better than $O(N^2)$ scaling, which becomes important for larger molecules. Recall that our message-passing model uses a cutoff when expanding displacement vectors in basis functions. While it doesn't hurt to include interactions beyond the cutoff in the index lists (they will simply contribute nothing to the message received by the destination atom), it is not very efficient to do so. In a real application, it would be better to construct the index lists using some spatial partitioning method, such that only interactions within the cutoff distance are included. With this trick, evaluating the message-passing model scales $O(NM)$, where $M \ll N$ is the average number of atoms within the cutoff distance.

# %%
def prepare_batches(key, data, batch_size):
  # Determine the number of training steps per epoch.
  data_size = len(data['energy'])
  steps_per_epoch = data_size//batch_size

  # Draw random permutations for fetching batches from the train data.
  perms = jax.random.permutation(key, data_size)
  perms = perms[:steps_per_epoch * batch_size]  # Skip the last batch (if incomplete).
  perms = perms.reshape((steps_per_epoch, batch_size))

  # Prepare entries that are identical for each batch.
  num_atoms = len(data['atomic_numbers'][0])
  batch_segments = jnp.repeat(jnp.arange(batch_size), num_atoms)
  # atomic_numbers = jnp.tile(data['atomic_numbers'], batch_size)
  offsets = jnp.arange(batch_size) * num_atoms
  dst_idx, src_idx = e3x.ops.sparse_pairwise_indices(num_atoms)
  dst_idx = (dst_idx + offsets[:, None]).reshape(-1)
  src_idx = (src_idx + offsets[:, None]).reshape(-1)

  # Assemble and return batches.
  return [
    dict(
        energy=data['energy'][perm],
        forces=data['forces'][perm].reshape(-1, 3),
        atomic_numbers=data["atomic_numbers"][perm].reshape(-1),
        positions=data['positions'][perm].reshape(-1, 3),
        dst_idx=dst_idx,
        src_idx=src_idx,
        batch_segments = batch_segments,
    )
    for perm in perms
  ]

# %% [markdown]
# Next, we define our loss function. As is common for regression tasks, we choose the $L_2$ (squared error) loss. Since we want to fit two different quantities at once (energy and forces), we simply add their respective losses together. We also add a weighting factor that allows us to tune the relative importance of the different loss terms. For convenience, we also define a function to compute the mean absolute errors, for keeping track of the model performance during training.

# %%
def mean_squared_loss(energy_prediction, energy_target, forces_prediction, forces_target, forces_weight):
  energy_loss = jnp.mean(optax.l2_loss(energy_prediction, energy_target))
  forces_loss = jnp.mean(optax.l2_loss(forces_prediction, forces_target))
  return energy_loss + forces_weight * forces_loss

def mean_absolute_error(prediction, target):
  return jnp.mean(jnp.abs(prediction - target))

# %% [markdown]
# Now that we have all the ingredients, we need to write some boilerplate for training models.

# %%
@functools.partial(jax.jit, static_argnames=('model_apply', 'optimizer_update', 'batch_size'))
def train_step(model_apply, optimizer_update, batch, batch_size, forces_weight, opt_state, params):
    
  def loss_fn(params):
    energy, forces = model_apply(
      params,
      atomic_numbers=batch['atomic_numbers'],
      positions=batch['positions'],
      dst_idx=batch['dst_idx'],
      src_idx=batch['src_idx'],
      batch_segments=batch['batch_segments'],
      batch_size=batch_size
    )
    loss = mean_squared_loss(
      energy_prediction=energy,
      energy_target=batch['energy'],
      forces_prediction=forces,
      forces_target=batch['forces'],
      forces_weight=forces_weight
    )
    return loss, (energy, forces)
  (loss, (energy, forces)), grad = jax.value_and_grad(loss_fn, has_aux=True)(params)
  updates, opt_state = optimizer_update(grad, opt_state, params)
  params = optax.apply_updates(params, updates)
  energy_mae = mean_absolute_error(energy, batch['energy'])
  forces_mae = mean_absolute_error(forces, batch['forces'])
  return params, opt_state, loss, energy_mae, forces_mae


@functools.partial(jax.jit, static_argnames=('model_apply', 'batch_size'))
def eval_step(model_apply, batch, batch_size, forces_weight, params):

  # for k,v in batch.items():
  #     print(k, v.shape)
    
  energy, forces = model_apply(
    params,
    atomic_numbers=batch['atomic_numbers'],
    positions=batch['positions'],
    dst_idx=batch['dst_idx'],
    src_idx=batch['src_idx'],
    batch_segments=batch['batch_segments'],
    batch_size=batch_size
  )
  loss = mean_squared_loss(
    energy_prediction=energy,
    energy_target=batch['energy'],
    forces_prediction=forces,
    forces_target=batch['forces'],
    forces_weight=forces_weight
  )
  energy_mae = mean_absolute_error(energy, batch['energy'])
  forces_mae = mean_absolute_error(forces, batch['forces'])
  return loss, energy_mae, forces_mae


def train_model(key, model, train_data, valid_data, num_epochs, learning_rate, forces_weight, batch_size):
  # Initialize model parameters and optimizer state.
  key, init_key = jax.random.split(key)
  optimizer = optax.adam(learning_rate)
  dst_idx, src_idx = e3x.ops.sparse_pairwise_indices(len(train_data['atomic_numbers'][0]))
  params = model.init(init_key,
    atomic_numbers=train_data['atomic_numbers'][0],
    positions=train_data['positions'][0],
    dst_idx=dst_idx,
    src_idx=src_idx,
  )
  opt_state = optimizer.init(params)

  # Batches for the validation set need to be prepared only once.
  key, shuffle_key = jax.random.split(key)
  valid_batches = prepare_batches(shuffle_key, valid_data, batch_size)

  # Train for 'num_epochs' epochs.
  for epoch in range(1, num_epochs + 1):
    # Prepare batches.
    key, shuffle_key = jax.random.split(key)
    train_batches = prepare_batches(shuffle_key, train_data, batch_size)

    # Loop over train batches.
    train_loss = 0.0
    train_energy_mae = 0.0
    train_forces_mae = 0.0
    for i, batch in enumerate(train_batches):
      params, opt_state, loss, energy_mae, forces_mae = train_step(
        model_apply=model.apply,
        optimizer_update=optimizer.update,
        batch=batch,
        batch_size=batch_size,
        forces_weight=forces_weight,
        opt_state=opt_state,
        params=params
      )
      train_loss += (loss - train_loss)/(i+1)
      train_energy_mae += (energy_mae - train_energy_mae)/(i+1)
      train_forces_mae += (forces_mae - train_forces_mae)/(i+1)

    # Evaluate on validation set.
    valid_loss = 0.0
    valid_energy_mae = 0.0
    valid_forces_mae = 0.0
    for i, batch in enumerate(valid_batches):
      loss, energy_mae, forces_mae = eval_step(
        model_apply=model.apply,
        batch=batch,
        batch_size=batch_size,
        forces_weight=forces_weight,
        params=params
      )
      valid_loss += (loss - valid_loss)/(i+1)
      valid_energy_mae += (energy_mae - valid_energy_mae)/(i+1)
      valid_forces_mae += (forces_mae - valid_forces_mae)/(i+1)

    # Print progress.
    print(f"epoch: {epoch: 3d}                    train:   valid:")
    print(f"    loss [a.u.]             {train_loss : 8.3f} {valid_loss : 8.3f}")
    print(f"    energy mae [kcal/mol]   {train_energy_mae: 8.3f} {valid_energy_mae: 8.3f}")
    print(f"    forces mae [kcal/mol/Å] {train_forces_mae: 8.3f} {valid_forces_mae: 8.3f}")


  # Return final model parameters.
  return params

# %% [markdown]
# The last step before training the model is to define the hyperparamters.

# %%
# Model hyperparameters.
features = 32
max_degree = 2
num_iterations = 3
num_basis_functions = 16
cutoff = 5.0

# Training hyperparameters.
num_valid = 10000
num_train = 26990 - num_valid
num_epochs = 1000
learning_rate = 0.0001
forces_weight = 1.0
batch_size = 496

# %%
jax.default_backend()
jax.devices()
# Out:
# [cuda(id=0), cuda(id=1)]

# %% [markdown]
# Finally, we can train our model.

# %%
# Create PRNGKeys.|
data_key, train_key = jax.random.split(jax.random.PRNGKey(0), 2)
# Draw training and validation sets.
train_data, valid_data, _ = prepare_datasets(data_key, num_train=num_train, num_valid=num_valid)
# Out:
# N (26994,)
# E (26994,)
# Q (26994,)
# D (26994, 3)
# z (26994, 3)
# R (26994, 3, 3)
# F (26994, 3, 3)
# 26994
# atomic_numbers (26994, 3)
# energy (16990,)
# forces (16990, 3, 3)
# atomic_numbers (16990, 3)
# positions (16990, 3, 3)
# energy (10000,)
# forces (10000, 3, 3)
# atomic_numbers (10000, 3)
# positions (10000, 3, 3)

# %%
train_data["energy"]
# Out:
# Array([ -9.973012,  -9.99556 , -10.004458, ...,  -9.905416, -10.004886,
#         -9.996991], dtype=float32)

# %%
train_data["atomic_numbers"].shape
# Out:
# (16990, 3)

# %% [markdown]
# Even a very simple model can achieve energy prediction errors well below 1 kcal/mol ("chemical accuracy") after training for a hundred epochs (the model is not converged yet, but it's good enough for now).
#
# Once the model is trained, we can use it as a force field, e.g. to do structure optimization, or to run molecular dynamics simulations. To demonstrate this, we use the atomic simulation environment (ASE) and py3Dmol (for visualization), so a few additional imports are necessary.

# %%
# params

# %%
# Create and train model.
message_passing_model = MessagePassingModel(
  features=features,
  max_degree=max_degree,
  num_iterations=num_iterations,
  num_basis_functions=num_basis_functions,
  cutoff=cutoff,
)

# %%
params = train_model(
  key=train_key,
  model=message_passing_model,
  train_data=train_data,
  valid_data=valid_data,
  num_epochs=num_epochs,
  learning_rate=learning_rate,
  forces_weight=forces_weight,
  batch_size=batch_size,
)
# Out:
# epoch:   1                    train:   valid:
#     loss [a.u.]               49.771   49.463
#     energy mae [kcal/mol]      9.930    9.899
#     forces mae [kcal/mol/Å]    0.537    0.536
# epoch:   2                    train:   valid:
#     loss [a.u.]               48.985   48.346
#     energy mae [kcal/mol]      9.850    9.785
#     forces mae [kcal/mol/Å]    0.537    0.536
# epoch:   3                    train:   valid:
#     loss [a.u.]               47.295   45.843
#     energy mae [kcal/mol]      9.677    9.526
#     forces mae [kcal/mol/Å]    0.537    0.536
# epoch:   4                    train:   valid:
#     loss [a.u.]               43.417   40.028
#     energy mae [kcal/mol]      9.267    8.895
#     forces mae [kcal/mol/Å]    0.536    0.537
# epoch:   5                    train:   valid:
#     loss [a.u.]               34.533   27.115
#     energy mae [kcal/mol]      8.241    7.300
#     forces mae [kcal/mol/Å]    0.539    0.539
# epoch:   6                    train:   valid:
#     loss [a.u.]               17.369    6.864
#     energy mae [kcal/mol]      5.715    3.576
#     forces mae [kcal/mol/Å]    0.541    0.543
# epoch:   7                    train:   valid:
#     loss [a.u.]                2.072    0.529
#     energy mae [kcal/mol]      1.383    0.350
#     forces mae [kcal/mol/Å]    0.545    0.546
# epoch:   8                    train:   valid:
#     loss [a.u.]                0.504    0.469
#     energy mae [kcal/mol]      0.228    0.090
#     forces mae [kcal/mol/Å]    0.545    0.544
# epoch:   9                    train:   valid:
#     loss [a.u.]                0.471    0.467
#     energy mae [kcal/mol]      0.084    0.055
#     forces mae [kcal/mol/Å]    0.545    0.543
# epoch:  10                    train:   valid:
#     loss [a.u.]                0.468    0.467
#     energy mae [kcal/mol]      0.056    0.059
#     forces mae [kcal/mol/Å]    0.543    0.542
# epoch:  11                    train:   valid:
#     loss [a.u.]                0.468    0.466
#     energy mae [kcal/mol]      0.060    0.058
#     forces mae [kcal/mol/Å]    0.542    0.541
# epoch:  12                    train:   valid:
#     loss [a.u.]                0.468    0.465
#     energy mae [kcal/mol]      0.060    0.058
#     forces mae [kcal/mol/Å]    0.541    0.540
# epoch:  13                    train:   valid:
#     loss [a.u.]                0.468    0.465
#     energy mae [kcal/mol]      0.059    0.058
#     forces mae [kcal/mol/Å]    0.541    0.539
# epoch:  14                    train:   valid:
#     loss [a.u.]                0.466    0.464
#     energy mae [kcal/mol]      0.059    0.059
#     forces mae [kcal/mol/Å]    0.539    0.538
# epoch:  15                    train:   valid:
#     loss [a.u.]                0.467    0.464
#     energy mae [kcal/mol]      0.059    0.058
#     forces mae [kcal/mol/Å]    0.539    0.537
# epoch:  16                    train:   valid:
#     loss [a.u.]                0.464    0.463
#     energy mae [kcal/mol]      0.059    0.057
#     forces mae [kcal/mol/Å]    0.537    0.536
# epoch:  17                    train:   valid:
#     loss [a.u.]                0.464    0.462
#     energy mae [kcal/mol]      0.059    0.058
#     forces mae [kcal/mol/Å]    0.536    0.535
# epoch:  18                    train:   valid:
#     loss [a.u.]                0.464    0.462
#     energy mae [kcal/mol]      0.059    0.058
#     forces mae [kcal/mol/Å]    0.535    0.534
# epoch:  19                    train:   valid:
#     loss [a.u.]                0.464    0.461
#     energy mae [kcal/mol]      0.059    0.058
#     forces mae [kcal/mol/Å]    0.535    0.533
# epoch:  20                    train:   valid:
#     loss [a.u.]                0.461    0.461
#     energy mae [kcal/mol]      0.059    0.058
#     forces mae [kcal/mol/Å]    0.533    0.532
# epoch:  21                    train:   valid:
#     loss [a.u.]                0.463    0.460
#     energy mae [kcal/mol]      0.059    0.058
#     forces mae [kcal/mol/Å]    0.533    0.531
# epoch:  22                    train:   valid:
#     loss [a.u.]                0.462    0.460
#     energy mae [kcal/mol]      0.059    0.056
#     forces mae [kcal/mol/Å]    0.531    0.530
# epoch:  23                    train:   valid:
#     loss [a.u.]                0.461    0.459
#     energy mae [kcal/mol]      0.059    0.059
#     forces mae [kcal/mol/Å]    0.530    0.529
# epoch:  24                    train:   valid:
#     loss [a.u.]                0.459    0.458
#     energy mae [kcal/mol]      0.059    0.057
#     forces mae [kcal/mol/Å]    0.529    0.528
# epoch:  25                    train:   valid:
#     loss [a.u.]                0.460    0.458
#     energy mae [kcal/mol]      0.058    0.058
#     forces mae [kcal/mol/Å]    0.528    0.527
# epoch:  26                    train:   valid:
#     loss [a.u.]                0.459    0.457
#     energy mae [kcal/mol]      0.059    0.056
#     forces mae [kcal/mol/Å]    0.527    0.526
# epoch:  27                    train:   valid:
#     loss [a.u.]                0.460    0.456
#     energy mae [kcal/mol]      0.059    0.058
#     forces mae [kcal/mol/Å]    0.526    0.524
# epoch:  28                    train:   valid:
#     loss [a.u.]                0.458    0.456
#     energy mae [kcal/mol]      0.058    0.059
#     forces mae [kcal/mol/Å]    0.525    0.523
# epoch:  29                    train:   valid:
#     loss [a.u.]                0.458    0.455
#     energy mae [kcal/mol]      0.059    0.056
#     forces mae [kcal/mol/Å]    0.524    0.521
# epoch:  30                    train:   valid:
#     loss [a.u.]                0.455    0.454
#     energy mae [kcal/mol]      0.058    0.057
#     forces mae [kcal/mol/Å]    0.522    0.520
# epoch:  31                    train:   valid:
#     loss [a.u.]                0.455    0.453
#     energy mae [kcal/mol]      0.058    0.056
#     forces mae [kcal/mol/Å]    0.520    0.518
# epoch:  32                    train:   valid:
#     loss [a.u.]                0.453    0.452
#     energy mae [kcal/mol]      0.058    0.056
#     forces mae [kcal/mol/Å]    0.518    0.516
# epoch:  33                    train:   valid:
#     loss [a.u.]                0.453    0.450
#     energy mae [kcal/mol]      0.057    0.056
#     forces mae [kcal/mol/Å]    0.516    0.514
# epoch:  34                    train:   valid:
#     loss [a.u.]                0.451    0.449
#     energy mae [kcal/mol]      0.057    0.056
#     forces mae [kcal/mol/Å]    0.514    0.511
# epoch:  35                    train:   valid:
#     loss [a.u.]                0.449    0.447
#     energy mae [kcal/mol]      0.057    0.057
#     forces mae [kcal/mol/Å]    0.511    0.509
# epoch:  36                    train:   valid:
#     loss [a.u.]                0.448    0.446
#     energy mae [kcal/mol]      0.056    0.057
#     forces mae [kcal/mol/Å]    0.509    0.507
# epoch:  37                    train:   valid:
#     loss [a.u.]                0.446    0.444
#     energy mae [kcal/mol]      0.056    0.057
#     forces mae [kcal/mol/Å]    0.507    0.504
# epoch:  38                    train:   valid:
#     loss [a.u.]                0.443    0.442
#     energy mae [kcal/mol]      0.056    0.054
#     forces mae [kcal/mol/Å]    0.504    0.502
# epoch:  39                    train:   valid:
#     loss [a.u.]                0.443    0.440
#     energy mae [kcal/mol]      0.056    0.055
#     forces mae [kcal/mol/Å]    0.502    0.500
# epoch:  40                    train:   valid:
#     loss [a.u.]                0.439    0.438
#     energy mae [kcal/mol]      0.056    0.055
#     forces mae [kcal/mol/Å]    0.500    0.499
# epoch:  41                    train:   valid:
#     loss [a.u.]                0.437    0.436
#     energy mae [kcal/mol]      0.055    0.054
#     forces mae [kcal/mol/Å]    0.498    0.497
# epoch:  42                    train:   valid:
#     loss [a.u.]                0.436    0.434
#     energy mae [kcal/mol]      0.056    0.055
#     forces mae [kcal/mol/Å]    0.497    0.496
# epoch:  43                    train:   valid:
#     loss [a.u.]                0.435    0.431
#     energy mae [kcal/mol]      0.055    0.054
#     forces mae [kcal/mol/Å]    0.496    0.494
# epoch:  44                    train:   valid:
#     loss [a.u.]                0.431    0.429
#     energy mae [kcal/mol]      0.055    0.054
#     forces mae [kcal/mol/Å]    0.494    0.493
# epoch:  45                    train:   valid:
#     loss [a.u.]                0.428    0.426
#     energy mae [kcal/mol]      0.054    0.051
#     forces mae [kcal/mol/Å]    0.493    0.491
# epoch:  46                    train:   valid:
#     loss [a.u.]                0.425    0.422
#     energy mae [kcal/mol]      0.054    0.051
#     forces mae [kcal/mol/Å]    0.491    0.489
# epoch:  47                    train:   valid:
#     loss [a.u.]                0.419    0.418
#     energy mae [kcal/mol]      0.053    0.049
#     forces mae [kcal/mol/Å]    0.488    0.487
# epoch:  48                    train:   valid:
#     loss [a.u.]                0.416    0.414
#     energy mae [kcal/mol]      0.052    0.052
#     forces mae [kcal/mol/Å]    0.486    0.484
# epoch:  49                    train:   valid:
#     loss [a.u.]                0.410    0.408
#     energy mae [kcal/mol]      0.051    0.048
#     forces mae [kcal/mol/Å]    0.483    0.481
# epoch:  50                    train:   valid:
#     loss [a.u.]                0.405    0.402
#     energy mae [kcal/mol]      0.049    0.049
#     forces mae [kcal/mol/Å]    0.480    0.477
# epoch:  51                    train:   valid:
#     loss [a.u.]                0.398    0.394
#     energy mae [kcal/mol]      0.048    0.046
#     forces mae [kcal/mol/Å]    0.475    0.472
# epoch:  52                    train:   valid:
#     loss [a.u.]                0.390    0.384
#     energy mae [kcal/mol]      0.046    0.046
#     forces mae [kcal/mol/Å]    0.470    0.466
# epoch:  53                    train:   valid:
#     loss [a.u.]                0.377    0.373
#     energy mae [kcal/mol]      0.043    0.041
#     forces mae [kcal/mol/Å]    0.462    0.458
# epoch:  54                    train:   valid:
#     loss [a.u.]                0.367    0.358
#     energy mae [kcal/mol]      0.040    0.039
#     forces mae [kcal/mol/Å]    0.455    0.449
# epoch:  55                    train:   valid:
#     loss [a.u.]                0.349    0.341
#     energy mae [kcal/mol]      0.037    0.035
#     forces mae [kcal/mol/Å]    0.443    0.436
# epoch:  56                    train:   valid:
#     loss [a.u.]                0.332    0.321
#     energy mae [kcal/mol]      0.034    0.032
#     forces mae [kcal/mol/Å]    0.430    0.421
# epoch:  57                    train:   valid:
#     loss [a.u.]                0.310    0.300
#     energy mae [kcal/mol]      0.031    0.030
#     forces mae [kcal/mol/Å]    0.413    0.404
# epoch:  58                    train:   valid:
#     loss [a.u.]                0.289    0.277
#     energy mae [kcal/mol]      0.030    0.029
#     forces mae [kcal/mol/Å]    0.396    0.386
# epoch:  59                    train:   valid:
#     loss [a.u.]                0.266    0.256
#     energy mae [kcal/mol]      0.031    0.030
#     forces mae [kcal/mol/Å]    0.377    0.369
# epoch:  60                    train:   valid:
#     loss [a.u.]                0.247    0.237
#     energy mae [kcal/mol]      0.032    0.033
#     forces mae [kcal/mol/Å]    0.362    0.353
# epoch:  61                    train:   valid:
#     loss [a.u.]                0.229    0.220
#     energy mae [kcal/mol]      0.031    0.028
#     forces mae [kcal/mol/Å]    0.347    0.340
# epoch:  62                    train:   valid:
#     loss [a.u.]                0.212    0.205
#     energy mae [kcal/mol]      0.030    0.025
#     forces mae [kcal/mol/Å]    0.335    0.327
# epoch:  63                    train:   valid:
#     loss [a.u.]                0.198    0.190
#     energy mae [kcal/mol]      0.029    0.027
#     forces mae [kcal/mol/Å]    0.322    0.315
# epoch:  64                    train:   valid:
#     loss [a.u.]                0.184    0.177
#     energy mae [kcal/mol]      0.029    0.025
#     forces mae [kcal/mol/Å]    0.310    0.302
# epoch:  65                    train:   valid:
#     loss [a.u.]                0.170    0.164
#     energy mae [kcal/mol]      0.027    0.033
#     forces mae [kcal/mol/Å]    0.297    0.291
# epoch:  66                    train:   valid:
#     loss [a.u.]                0.158    0.151
#     energy mae [kcal/mol]      0.028    0.025
#     forces mae [kcal/mol/Å]    0.285    0.277
# epoch:  67                    train:   valid:
#     loss [a.u.]                0.145    0.138
#     energy mae [kcal/mol]      0.026    0.023
#     forces mae [kcal/mol/Å]    0.271    0.264
# epoch:  68                    train:   valid:
#     loss [a.u.]                0.133    0.126
#     energy mae [kcal/mol]      0.026    0.022
#     forces mae [kcal/mol/Å]    0.258    0.250
# epoch:  69                    train:   valid:
#     loss [a.u.]                0.121    0.114
#     energy mae [kcal/mol]      0.025    0.019
#     forces mae [kcal/mol/Å]    0.244    0.236
# epoch:  70                    train:   valid:
#     loss [a.u.]                0.109    0.102
#     energy mae [kcal/mol]      0.024    0.021
#     forces mae [kcal/mol/Å]    0.230    0.221
# epoch:  71                    train:   valid:
#     loss [a.u.]                0.097    0.091
#     energy mae [kcal/mol]      0.024    0.023
#     forces mae [kcal/mol/Å]    0.215    0.205
# epoch:  72                    train:   valid:
#     loss [a.u.]                0.086    0.080
#     energy mae [kcal/mol]      0.023    0.024
#     forces mae [kcal/mol/Å]    0.198    0.190
# epoch:  73                    train:   valid:
#     loss [a.u.]                0.076    0.070
#     energy mae [kcal/mol]      0.022    0.021
#     forces mae [kcal/mol/Å]    0.183    0.173
# epoch:  74                    train:   valid:
#     loss [a.u.]                0.066    0.060
#     energy mae [kcal/mol]      0.020    0.024
#     forces mae [kcal/mol/Å]    0.167    0.159
# epoch:  75                    train:   valid:
#     loss [a.u.]                0.057    0.052
#     energy mae [kcal/mol]      0.020    0.018
#     forces mae [kcal/mol/Å]    0.151    0.142
# epoch:  76                    train:   valid:
#     loss [a.u.]                0.049    0.044
#     energy mae [kcal/mol]      0.018    0.019
#     forces mae [kcal/mol/Å]    0.135    0.127
# epoch:  77                    train:   valid:
#     loss [a.u.]                0.042    0.038
#     energy mae [kcal/mol]      0.017    0.017
#     forces mae [kcal/mol/Å]    0.121    0.113
# epoch:  78                    train:   valid:
#     loss [a.u.]                0.036    0.032
#     energy mae [kcal/mol]      0.015    0.018
#     forces mae [kcal/mol/Å]    0.108    0.101
# epoch:  79                    train:   valid:
#     loss [a.u.]                0.031    0.028
#     energy mae [kcal/mol]      0.014    0.015
#     forces mae [kcal/mol/Å]    0.096    0.090
# epoch:  80                    train:   valid:
#     loss [a.u.]                0.027    0.024
#     energy mae [kcal/mol]      0.012    0.010
#     forces mae [kcal/mol/Å]    0.086    0.080
# epoch:  81                    train:   valid:
#     loss [a.u.]                0.024    0.022
#     energy mae [kcal/mol]      0.011    0.009
#     forces mae [kcal/mol/Å]    0.078    0.073
# epoch:  82                    train:   valid:
#     loss [a.u.]                0.022    0.020
#     energy mae [kcal/mol]      0.009    0.007
#     forces mae [kcal/mol/Å]    0.071    0.066
# epoch:  83                    train:   valid:
#     loss [a.u.]                0.020    0.018
#     energy mae [kcal/mol]      0.008    0.009
#     forces mae [kcal/mol/Å]    0.067    0.064
# epoch:  84                    train:   valid:
#     loss [a.u.]                0.018    0.017
#     energy mae [kcal/mol]      0.007    0.006
#     forces mae [kcal/mol/Å]    0.064    0.062
# epoch:  85                    train:   valid:
#     loss [a.u.]                0.017    0.016
#     energy mae [kcal/mol]      0.007    0.006
#     forces mae [kcal/mol/Å]    0.062    0.060
# epoch:  86                    train:   valid:
#     loss [a.u.]                0.017    0.016
#     energy mae [kcal/mol]      0.006    0.005
#     forces mae [kcal/mol/Å]    0.061    0.061
# epoch:  87                    train:   valid:
#     loss [a.u.]                0.016    0.015
#     energy mae [kcal/mol]      0.005    0.004
#     forces mae [kcal/mol/Å]    0.061    0.058
# epoch:  88                    train:   valid:
#     loss [a.u.]                0.015    0.015
#     energy mae [kcal/mol]      0.005    0.005
#     forces mae [kcal/mol/Å]    0.060    0.060
# epoch:  89                    train:   valid:
#     loss [a.u.]                0.015    0.014
#     energy mae [kcal/mol]      0.005    0.003
#     forces mae [kcal/mol/Å]    0.060    0.059
# epoch:  90                    train:   valid:
#     loss [a.u.]                0.015    0.014
#     energy mae [kcal/mol]      0.004    0.006
#     forces mae [kcal/mol/Å]    0.060    0.059
# epoch:  91                    train:   valid:
#     loss [a.u.]                0.015    0.014
#     energy mae [kcal/mol]      0.005    0.003
#     forces mae [kcal/mol/Å]    0.060    0.059
# epoch:  92                    train:   valid:
#     loss [a.u.]                0.014    0.014
#     energy mae [kcal/mol]      0.004    0.005
#     forces mae [kcal/mol/Å]    0.060    0.059
# epoch:  93                    train:   valid:
#     loss [a.u.]                0.014    0.013
#     energy mae [kcal/mol]      0.004    0.005
#     forces mae [kcal/mol/Å]    0.060    0.058
# epoch:  94                    train:   valid:
#     loss [a.u.]                0.014    0.013
#     energy mae [kcal/mol]      0.004    0.003
#     forces mae [kcal/mol/Å]    0.059    0.060
# epoch:  95                    train:   valid:
#     loss [a.u.]                0.014    0.013
#     energy mae [kcal/mol]      0.004    0.005
#     forces mae [kcal/mol/Å]    0.059    0.058
# epoch:  96                    train:   valid:
#     loss [a.u.]                0.013    0.013
#     energy mae [kcal/mol]      0.004    0.004
#     forces mae [kcal/mol/Å]    0.059    0.058
# epoch:  97                    train:   valid:
#     loss [a.u.]                0.013    0.012
#     energy mae [kcal/mol]      0.004    0.003
#     forces mae [kcal/mol/Å]    0.058    0.057
# epoch:  98                    train:   valid:
#     loss [a.u.]                0.013    0.012
#     energy mae [kcal/mol]      0.004    0.005
#     forces mae [kcal/mol/Å]    0.058    0.057
# epoch:  99                    train:   valid:
#     loss [a.u.]                0.013    0.012
#     energy mae [kcal/mol]      0.004    0.003
#     forces mae [kcal/mol/Å]    0.057    0.059
# epoch:  100                    train:   valid:
#     loss [a.u.]                0.013    0.012
#     energy mae [kcal/mol]      0.004    0.003
#     forces mae [kcal/mol/Å]    0.058    0.056
# epoch:  101                    train:   valid:
#     loss [a.u.]                0.012    0.012
#     energy mae [kcal/mol]      0.004    0.004
#     forces mae [kcal/mol/Å]    0.057    0.056
# epoch:  102                    train:   valid:
#     loss [a.u.]                0.012    0.012
#     energy mae [kcal/mol]      0.005    0.004
#     forces mae [kcal/mol/Å]    0.057    0.055
# epoch:  103                    train:   valid:
#     loss [a.u.]                0.012    0.011
#     energy mae [kcal/mol]      0.004    0.004
#     forces mae [kcal/mol/Å]    0.057    0.055
# epoch:  104                    train:   valid:
#     loss [a.u.]                0.012    0.011
#     energy mae [kcal/mol]      0.004    0.004
#     forces mae [kcal/mol/Å]    0.056    0.055
# epoch:  105                    train:   valid:
#     loss [a.u.]                0.012    0.011
#     energy mae [kcal/mol]      0.003    0.002
#     forces mae [kcal/mol/Å]    0.056    0.055
# epoch:  106                    train:   valid:
#     loss [a.u.]                0.011    0.011
#     energy mae [kcal/mol]      0.004    0.003
#     forces mae [kcal/mol/Å]    0.055    0.055
# epoch:  107                    train:   valid:
#     loss [a.u.]                0.011    0.011
#     energy mae [kcal/mol]      0.003    0.003
#     forces mae [kcal/mol/Å]    0.055    0.055
# epoch:  108                    train:   valid:
#     loss [a.u.]                0.011    0.011
#     energy mae [kcal/mol]      0.003    0.003
#     forces mae [kcal/mol/Å]    0.055    0.054
# epoch:  109                    train:   valid:
#     loss [a.u.]                0.011    0.010
#     energy mae [kcal/mol]      0.003    0.002
#     forces mae [kcal/mol/Å]    0.055    0.053
# epoch:  110                    train:   valid:
#     loss [a.u.]                0.011    0.010
#     energy mae [kcal/mol]      0.003    0.004
#     forces mae [kcal/mol/Å]    0.054    0.053
# epoch:  111                    train:   valid:
#     loss [a.u.]                0.011    0.010
#     energy mae [kcal/mol]      0.004    0.003
#     forces mae [kcal/mol/Å]    0.054    0.054
# epoch:  112                    train:   valid:
#     loss [a.u.]                0.011    0.010
#     energy mae [kcal/mol]      0.003    0.002
#     forces mae [kcal/mol/Å]    0.053    0.053
# epoch:  113                    train:   valid:
#     loss [a.u.]                0.011    0.010
#     energy mae [kcal/mol]      0.003    0.005
#     forces mae [kcal/mol/Å]    0.053    0.052
# epoch:  114                    train:   valid:
#     loss [a.u.]                0.010    0.010
#     energy mae [kcal/mol]      0.003    0.004
#     forces mae [kcal/mol/Å]    0.053    0.052
# epoch:  115                    train:   valid:
#     loss [a.u.]                0.010    0.010
#     energy mae [kcal/mol]      0.003    0.002
#     forces mae [kcal/mol/Å]    0.053    0.053
# epoch:  116                    train:   valid:
#     loss [a.u.]                0.010    0.009
#     energy mae [kcal/mol]      0.003    0.002
#     forces mae [kcal/mol/Å]    0.052    0.051
# epoch:  117                    train:   valid:
#     loss [a.u.]                0.010    0.009
#     energy mae [kcal/mol]      0.003    0.003
#     forces mae [kcal/mol/Å]    0.052    0.051
# epoch:  118                    train:   valid:
#     loss [a.u.]                0.010    0.009
#     energy mae [kcal/mol]      0.003    0.005
#     forces mae [kcal/mol/Å]    0.052    0.051
# epoch:  119                    train:   valid:
#     loss [a.u.]                0.010    0.009
#     energy mae [kcal/mol]      0.004    0.002
#     forces mae [kcal/mol/Å]    0.052    0.051
# epoch:  120                    train:   valid:
#     loss [a.u.]                0.010    0.009
#     energy mae [kcal/mol]      0.004    0.003
#     forces mae [kcal/mol/Å]    0.051    0.050
# epoch:  121                    train:   valid:
#     loss [a.u.]                0.009    0.009
#     energy mae [kcal/mol]      0.004    0.006
#     forces mae [kcal/mol/Å]    0.051    0.051
# epoch:  122                    train:   valid:
#     loss [a.u.]                0.009    0.009
#     energy mae [kcal/mol]      0.004    0.004
#     forces mae [kcal/mol/Å]    0.051    0.050
# epoch:  123                    train:   valid:
#     loss [a.u.]                0.009    0.009
#     energy mae [kcal/mol]      0.005    0.006
#     forces mae [kcal/mol/Å]    0.051    0.050
# epoch:  124                    train:   valid:
#     loss [a.u.]                0.009    0.009
#     energy mae [kcal/mol]      0.003    0.003
#     forces mae [kcal/mol/Å]    0.050    0.049
# epoch:  125                    train:   valid:
#     loss [a.u.]                0.009    0.008
#     energy mae [kcal/mol]      0.003    0.002
#     forces mae [kcal/mol/Å]    0.050    0.049
# epoch:  126                    train:   valid:
#     loss [a.u.]                0.009    0.008
#     energy mae [kcal/mol]      0.003    0.004
#     forces mae [kcal/mol/Å]    0.050    0.050
# epoch:  127                    train:   valid:
#     loss [a.u.]                0.009    0.008
#     energy mae [kcal/mol]      0.003    0.002
#     forces mae [kcal/mol/Å]    0.050    0.049
# epoch:  128                    train:   valid:
#     loss [a.u.]                0.009    0.008
#     energy mae [kcal/mol]      0.003    0.003
#     forces mae [kcal/mol/Å]    0.049    0.049
# epoch:  129                    train:   valid:
#     loss [a.u.]                0.008    0.008
#     energy mae [kcal/mol]      0.003    0.005
#     forces mae [kcal/mol/Å]    0.049    0.048
# epoch:  130                    train:   valid:
#     loss [a.u.]                0.008    0.008
#     energy mae [kcal/mol]      0.004    0.003
#     forces mae [kcal/mol/Å]    0.049    0.049
# epoch:  131                    train:   valid:
#     loss [a.u.]                0.008    0.008
#     energy mae [kcal/mol]      0.003    0.004
#     forces mae [kcal/mol/Å]    0.049    0.048
# epoch:  132                    train:   valid:
#     loss [a.u.]                0.008    0.008
#     energy mae [kcal/mol]      0.004    0.003
#     forces mae [kcal/mol/Å]    0.049    0.048
# epoch:  133                    train:   valid:
#     loss [a.u.]                0.008    0.008
#     energy mae [kcal/mol]      0.003    0.003
#     forces mae [kcal/mol/Å]    0.048    0.047
# epoch:  134                    train:   valid:
#     loss [a.u.]                0.008    0.007
#     energy mae [kcal/mol]      0.003    0.002
#     forces mae [kcal/mol/Å]    0.048    0.047
# epoch:  135                    train:   valid:
#     loss [a.u.]                0.008    0.007
#     energy mae [kcal/mol]      0.003    0.002
#     forces mae [kcal/mol/Å]    0.048    0.049
# epoch:  136                    train:   valid:
#     loss [a.u.]                0.008    0.007
#     energy mae [kcal/mol]      0.003    0.002
#     forces mae [kcal/mol/Å]    0.048    0.049
# epoch:  137                    train:   valid:
#     loss [a.u.]                0.008    0.007
#     energy mae [kcal/mol]      0.004    0.002
#     forces mae [kcal/mol/Å]    0.048    0.046
# epoch:  138                    train:   valid:
#     loss [a.u.]                0.008    0.007
#     energy mae [kcal/mol]      0.003    0.006
#     forces mae [kcal/mol/Å]    0.047    0.046
# epoch:  139                    train:   valid:
#     loss [a.u.]                0.007    0.007
#     energy mae [kcal/mol]      0.003    0.004
#     forces mae [kcal/mol/Å]    0.047    0.046
# epoch:  140                    train:   valid:
#     loss [a.u.]                0.007    0.007
#     energy mae [kcal/mol]      0.004    0.003
#     forces mae [kcal/mol/Å]    0.047    0.046
# epoch:  141                    train:   valid:
#     loss [a.u.]                0.007    0.007
#     energy mae [kcal/mol]      0.003    0.002
#     forces mae [kcal/mol/Å]    0.046    0.047
# epoch:  142                    train:   valid:
#     loss [a.u.]                0.007    0.007
#     energy mae [kcal/mol]      0.003    0.003
#     forces mae [kcal/mol/Å]    0.047    0.046
# epoch:  143                    train:   valid:
#     loss [a.u.]                0.007    0.007
#     energy mae [kcal/mol]      0.004    0.003
#     forces mae [kcal/mol/Å]    0.046    0.046
# epoch:  144                    train:   valid:
#     loss [a.u.]                0.007    0.007
#     energy mae [kcal/mol]      0.004    0.003
#     forces mae [kcal/mol/Å]    0.046    0.045
# epoch:  145                    train:   valid:
#     loss [a.u.]                0.007    0.007
#     energy mae [kcal/mol]      0.003    0.005
#     forces mae [kcal/mol/Å]    0.046    0.046
# epoch:  146                    train:   valid:
#     loss [a.u.]                0.007    0.006
#     energy mae [kcal/mol]      0.004    0.006
#     forces mae [kcal/mol/Å]    0.046    0.045
# epoch:  147                    train:   valid:
#     loss [a.u.]                0.007    0.006
#     energy mae [kcal/mol]      0.004    0.005
#     forces mae [kcal/mol/Å]    0.046    0.046
# epoch:  148                    train:   valid:
#     loss [a.u.]                0.007    0.006
#     energy mae [kcal/mol]      0.004    0.003
#     forces mae [kcal/mol/Å]    0.045    0.044
# epoch:  149                    train:   valid:
#     loss [a.u.]                0.007    0.006
#     energy mae [kcal/mol]      0.003    0.006
#     forces mae [kcal/mol/Å]    0.045    0.044
# epoch:  150                    train:   valid:
#     loss [a.u.]                0.007    0.006
#     energy mae [kcal/mol]      0.003    0.005
#     forces mae [kcal/mol/Å]    0.045    0.044
# epoch:  151                    train:   valid:
#     loss [a.u.]                0.006    0.006
#     energy mae [kcal/mol]      0.003    0.002
#     forces mae [kcal/mol/Å]    0.045    0.044
# epoch:  152                    train:   valid:
#     loss [a.u.]                0.006    0.006
#     energy mae [kcal/mol]      0.003    0.007
#     forces mae [kcal/mol/Å]    0.044    0.044
# epoch:  153                    train:   valid:
#     loss [a.u.]                0.006    0.006
#     energy mae [kcal/mol]      0.004    0.002
#     forces mae [kcal/mol/Å]    0.044    0.044
# epoch:  154                    train:   valid:
#     loss [a.u.]                0.006    0.006
#     energy mae [kcal/mol]      0.003    0.002
#     forces mae [kcal/mol/Å]    0.044    0.043
# epoch:  155                    train:   valid:
#     loss [a.u.]                0.006    0.006
#     energy mae [kcal/mol]      0.003    0.003
#     forces mae [kcal/mol/Å]    0.044    0.043
# epoch:  156                    train:   valid:
#     loss [a.u.]                0.006    0.006
#     energy mae [kcal/mol]      0.004    0.002
#     forces mae [kcal/mol/Å]    0.044    0.042
# epoch:  157                    train:   valid:
#     loss [a.u.]                0.006    0.006
#     energy mae [kcal/mol]      0.003    0.005
#     forces mae [kcal/mol/Å]    0.044    0.044
# epoch:  158                    train:   valid:
#     loss [a.u.]                0.006    0.006
#     energy mae [kcal/mol]      0.002    0.004
#     forces mae [kcal/mol/Å]    0.044    0.042
# epoch:  159                    train:   valid:
#     loss [a.u.]                0.006    0.006
#     energy mae [kcal/mol]      0.003    0.003
#     forces mae [kcal/mol/Å]    0.043    0.042
# epoch:  160                    train:   valid:
#     loss [a.u.]                0.006    0.005
#     energy mae [kcal/mol]      0.003    0.003
#     forces mae [kcal/mol/Å]    0.043    0.043
# epoch:  161                    train:   valid:
#     loss [a.u.]                0.006    0.005
#     energy mae [kcal/mol]      0.003    0.002
#     forces mae [kcal/mol/Å]    0.043    0.042
# epoch:  162                    train:   valid:
#     loss [a.u.]                0.006    0.005
#     energy mae [kcal/mol]      0.003    0.003
#     forces mae [kcal/mol/Å]    0.043    0.042
# epoch:  163                    train:   valid:
#     loss [a.u.]                0.006    0.005
#     energy mae [kcal/mol]      0.003    0.004
#     forces mae [kcal/mol/Å]    0.043    0.042
# epoch:  164                    train:   valid:
#     loss [a.u.]                0.006    0.005
#     energy mae [kcal/mol]      0.003    0.002
#     forces mae [kcal/mol/Å]    0.042    0.042
# epoch:  165                    train:   valid:
#     loss [a.u.]                0.005    0.005
#     energy mae [kcal/mol]      0.003    0.004
#     forces mae [kcal/mol/Å]    0.042    0.041
# epoch:  166                    train:   valid:
#     loss [a.u.]                0.005    0.005
#     energy mae [kcal/mol]      0.003    0.006
#     forces mae [kcal/mol/Å]    0.042    0.041
# epoch:  167                    train:   valid:
#     loss [a.u.]                0.005    0.005
#     energy mae [kcal/mol]      0.004    0.004
#     forces mae [kcal/mol/Å]    0.042    0.041
# epoch:  168                    train:   valid:
#     loss [a.u.]                0.005    0.005
#     energy mae [kcal/mol]      0.003    0.002
#     forces mae [kcal/mol/Å]    0.042    0.041
# epoch:  169                    train:   valid:
#     loss [a.u.]                0.005    0.005
#     energy mae [kcal/mol]      0.003    0.003
#     forces mae [kcal/mol/Å]    0.042    0.041
# epoch:  170                    train:   valid:
#     loss [a.u.]                0.005    0.005
#     energy mae [kcal/mol]      0.003    0.003
#     forces mae [kcal/mol/Å]    0.041    0.041
# epoch:  171                    train:   valid:
#     loss [a.u.]                0.005    0.005
#     energy mae [kcal/mol]      0.003    0.002
#     forces mae [kcal/mol/Å]    0.041    0.041
# epoch:  172                    train:   valid:
#     loss [a.u.]                0.005    0.005
#     energy mae [kcal/mol]      0.002    0.002
#     forces mae [kcal/mol/Å]    0.041    0.040
# epoch:  173                    train:   valid:
#     loss [a.u.]                0.005    0.005
#     energy mae [kcal/mol]      0.003    0.002
#     forces mae [kcal/mol/Å]    0.041    0.041
# epoch:  174                    train:   valid:
#     loss [a.u.]                0.005    0.005
#     energy mae [kcal/mol]      0.003    0.002
#     forces mae [kcal/mol/Å]    0.041    0.039
# epoch:  175                    train:   valid:
#     loss [a.u.]                0.005    0.005
#     energy mae [kcal/mol]      0.003    0.002
#     forces mae [kcal/mol/Å]    0.041    0.039
# epoch:  176                    train:   valid:
#     loss [a.u.]                0.005    0.005
#     energy mae [kcal/mol]      0.003    0.002
#     forces mae [kcal/mol/Å]    0.040    0.039
# epoch:  177                    train:   valid:
#     loss [a.u.]                0.005    0.004
#     energy mae [kcal/mol]      0.003    0.004
#     forces mae [kcal/mol/Å]    0.040    0.040
# epoch:  178                    train:   valid:
#     loss [a.u.]                0.005    0.004
#     energy mae [kcal/mol]      0.003    0.002
#     forces mae [kcal/mol/Å]    0.040    0.040
# epoch:  179                    train:   valid:
#     loss [a.u.]                0.005    0.004
#     energy mae [kcal/mol]      0.003    0.002
#     forces mae [kcal/mol/Å]    0.040    0.039
# epoch:  180                    train:   valid:
#     loss [a.u.]                0.005    0.004
#     energy mae [kcal/mol]      0.002    0.002
#     forces mae [kcal/mol/Å]    0.040    0.039
# epoch:  181                    train:   valid:
#     loss [a.u.]                0.005    0.004
#     energy mae [kcal/mol]      0.003    0.004
#     forces mae [kcal/mol/Å]    0.040    0.039
# epoch:  182                    train:   valid:
#     loss [a.u.]                0.005    0.004
#     energy mae [kcal/mol]      0.003    0.002
#     forces mae [kcal/mol/Å]    0.040    0.038
# epoch:  183                    train:   valid:
#     loss [a.u.]                0.004    0.004
#     energy mae [kcal/mol]      0.003    0.005
#     forces mae [kcal/mol/Å]    0.039    0.039
# epoch:  184                    train:   valid:
#     loss [a.u.]                0.004    0.004
#     energy mae [kcal/mol]      0.004    0.002
#     forces mae [kcal/mol/Å]    0.039    0.039
# epoch:  185                    train:   valid:
#     loss [a.u.]                0.004    0.004
#     energy mae [kcal/mol]      0.003    0.004
#     forces mae [kcal/mol/Å]    0.039    0.038
# epoch:  186                    train:   valid:
#     loss [a.u.]                0.004    0.004
#     energy mae [kcal/mol]      0.003    0.002
#     forces mae [kcal/mol/Å]    0.039    0.039
# epoch:  187                    train:   valid:
#     loss [a.u.]                0.004    0.004
#     energy mae [kcal/mol]      0.003    0.002
#     forces mae [kcal/mol/Å]    0.039    0.038
# epoch:  188                    train:   valid:
#     loss [a.u.]                0.004    0.004
#     energy mae [kcal/mol]      0.003    0.002
#     forces mae [kcal/mol/Å]    0.038    0.038
# epoch:  189                    train:   valid:
#     loss [a.u.]                0.004    0.004
#     energy mae [kcal/mol]      0.003    0.002
#     forces mae [kcal/mol/Å]    0.038    0.038
# epoch:  190                    train:   valid:
#     loss [a.u.]                0.004    0.004
#     energy mae [kcal/mol]      0.003    0.002
#     forces mae [kcal/mol/Å]    0.038    0.038
# epoch:  191                    train:   valid:
#     loss [a.u.]                0.004    0.004
#     energy mae [kcal/mol]      0.002    0.004
#     forces mae [kcal/mol/Å]    0.038    0.038
# epoch:  192                    train:   valid:
#     loss [a.u.]                0.004    0.004
#     energy mae [kcal/mol]      0.003    0.005
#     forces mae [kcal/mol/Å]    0.038    0.037
# epoch:  193                    train:   valid:
#     loss [a.u.]                0.004    0.004
#     energy mae [kcal/mol]      0.003    0.002
#     forces mae [kcal/mol/Å]    0.038    0.037
# epoch:  194                    train:   valid:
#     loss [a.u.]                0.004    0.004
#     energy mae [kcal/mol]      0.003    0.002
#     forces mae [kcal/mol/Å]    0.038    0.036
# epoch:  195                    train:   valid:
#     loss [a.u.]                0.004    0.004
#     energy mae [kcal/mol]      0.003    0.002
#     forces mae [kcal/mol/Å]    0.038    0.037
# epoch:  196                    train:   valid:
#     loss [a.u.]                0.004    0.004
#     energy mae [kcal/mol]      0.002    0.002
#     forces mae [kcal/mol/Å]    0.037    0.036
# epoch:  197                    train:   valid:
#     loss [a.u.]                0.004    0.004
#     energy mae [kcal/mol]      0.002    0.003
#     forces mae [kcal/mol/Å]    0.037    0.036
# epoch:  198                    train:   valid:
#     loss [a.u.]                0.004    0.003
#     energy mae [kcal/mol]      0.002    0.005
#     forces mae [kcal/mol/Å]    0.036    0.035
# epoch:  199                    train:   valid:
#     loss [a.u.]                0.004    0.003
#     energy mae [kcal/mol]      0.003    0.003
#     forces mae [kcal/mol/Å]    0.036    0.036
# epoch:  200                    train:   valid:
#     loss [a.u.]                0.004    0.003
#     energy mae [kcal/mol]      0.003    0.006
#     forces mae [kcal/mol/Å]    0.036    0.036
# epoch:  201                    train:   valid:
#     loss [a.u.]                0.004    0.003
#     energy mae [kcal/mol]      0.003    0.003
#     forces mae [kcal/mol/Å]    0.036    0.035
# epoch:  202                    train:   valid:
#     loss [a.u.]                0.004    0.003
#     energy mae [kcal/mol]      0.002    0.002
#     forces mae [kcal/mol/Å]    0.035    0.035
# epoch:  203                    train:   valid:
#     loss [a.u.]                0.003    0.003
#     energy mae [kcal/mol]      0.003    0.002
#     forces mae [kcal/mol/Å]    0.035    0.036
# epoch:  204                    train:   valid:
#     loss [a.u.]                0.003    0.003
#     energy mae [kcal/mol]      0.003    0.004
#     forces mae [kcal/mol/Å]    0.035    0.034
# epoch:  205                    train:   valid:
#     loss [a.u.]                0.003    0.003
#     energy mae [kcal/mol]      0.003    0.002
#     forces mae [kcal/mol/Å]    0.035    0.034
# epoch:  206                    train:   valid:
#     loss [a.u.]                0.003    0.003
#     energy mae [kcal/mol]      0.004    0.004
#     forces mae [kcal/mol/Å]    0.035    0.034
# epoch:  207                    train:   valid:
#     loss [a.u.]                0.003    0.003
#     energy mae [kcal/mol]      0.003    0.002
#     forces mae [kcal/mol/Å]    0.034    0.033
# epoch:  208                    train:   valid:
#     loss [a.u.]                0.003    0.003
#     energy mae [kcal/mol]      0.002    0.003
#     forces mae [kcal/mol/Å]    0.034    0.033
# epoch:  209                    train:   valid:
#     loss [a.u.]                0.003    0.003
#     energy mae [kcal/mol]      0.003    0.004
#     forces mae [kcal/mol/Å]    0.034    0.034
# epoch:  210                    train:   valid:
#     loss [a.u.]                0.003    0.003
#     energy mae [kcal/mol]      0.003    0.004
#     forces mae [kcal/mol/Å]    0.034    0.033
# epoch:  211                    train:   valid:
#     loss [a.u.]                0.003    0.003
#     energy mae [kcal/mol]      0.003    0.007
#     forces mae [kcal/mol/Å]    0.034    0.033
# epoch:  212                    train:   valid:
#     loss [a.u.]                0.003    0.003
#     energy mae [kcal/mol]      0.004    0.002
#     forces mae [kcal/mol/Å]    0.033    0.032
# epoch:  213                    train:   valid:
#     loss [a.u.]                0.003    0.003
#     energy mae [kcal/mol]      0.002    0.002
#     forces mae [kcal/mol/Å]    0.033    0.032
# epoch:  214                    train:   valid:
#     loss [a.u.]                0.003    0.003
#     energy mae [kcal/mol]      0.003    0.003
#     forces mae [kcal/mol/Å]    0.032    0.032
# epoch:  215                    train:   valid:
#     loss [a.u.]                0.003    0.003
#     energy mae [kcal/mol]      0.003    0.002
#     forces mae [kcal/mol/Å]    0.032    0.032
# epoch:  216                    train:   valid:
#     loss [a.u.]                0.003    0.003
#     energy mae [kcal/mol]      0.002    0.004
#     forces mae [kcal/mol/Å]    0.032    0.031
# epoch:  217                    train:   valid:
#     loss [a.u.]                0.003    0.002
#     energy mae [kcal/mol]      0.003    0.002
#     forces mae [kcal/mol/Å]    0.032    0.031
# epoch:  218                    train:   valid:
#     loss [a.u.]                0.003    0.002
#     energy mae [kcal/mol]      0.003    0.002
#     forces mae [kcal/mol/Å]    0.031    0.030
# epoch:  219                    train:   valid:
#     loss [a.u.]                0.003    0.002
#     energy mae [kcal/mol]      0.002    0.003
#     forces mae [kcal/mol/Å]    0.031    0.030
# epoch:  220                    train:   valid:
#     loss [a.u.]                0.003    0.002
#     energy mae [kcal/mol]      0.003    0.002
#     forces mae [kcal/mol/Å]    0.030    0.030
# epoch:  221                    train:   valid:
#     loss [a.u.]                0.002    0.002
#     energy mae [kcal/mol]      0.003    0.003
#     forces mae [kcal/mol/Å]    0.030    0.029
# epoch:  222                    train:   valid:
#     loss [a.u.]                0.002    0.002
#     energy mae [kcal/mol]      0.003    0.001
#     forces mae [kcal/mol/Å]    0.030    0.029
# epoch:  223                    train:   valid:
#     loss [a.u.]                0.002    0.002
#     energy mae [kcal/mol]      0.002    0.003
#     forces mae [kcal/mol/Å]    0.029    0.028
# epoch:  224                    train:   valid:
#     loss [a.u.]                0.002    0.002
#     energy mae [kcal/mol]      0.002    0.001
#     forces mae [kcal/mol/Å]    0.029    0.028
# epoch:  225                    train:   valid:
#     loss [a.u.]                0.002    0.002
#     energy mae [kcal/mol]      0.003    0.002
#     forces mae [kcal/mol/Å]    0.028    0.028
# epoch:  226                    train:   valid:
#     loss [a.u.]                0.002    0.002
#     energy mae [kcal/mol]      0.002    0.001
#     forces mae [kcal/mol/Å]    0.028    0.027
# epoch:  227                    train:   valid:
#     loss [a.u.]                0.002    0.002
#     energy mae [kcal/mol]      0.002    0.003
#     forces mae [kcal/mol/Å]    0.027    0.027
# epoch:  228                    train:   valid:
#     loss [a.u.]                0.002    0.002
#     energy mae [kcal/mol]      0.003    0.003
#     forces mae [kcal/mol/Å]    0.027    0.026
# epoch:  229                    train:   valid:
#     loss [a.u.]                0.002    0.002
#     energy mae [kcal/mol]      0.003    0.004
#     forces mae [kcal/mol/Å]    0.026    0.026
# epoch:  230                    train:   valid:
#     loss [a.u.]                0.002    0.002
#     energy mae [kcal/mol]      0.002    0.002
#     forces mae [kcal/mol/Å]    0.026    0.025
# epoch:  231                    train:   valid:
#     loss [a.u.]                0.002    0.002
#     energy mae [kcal/mol]      0.003    0.001
#     forces mae [kcal/mol/Å]    0.025    0.025
# epoch:  232                    train:   valid:
#     loss [a.u.]                0.002    0.002
#     energy mae [kcal/mol]      0.003    0.006
#     forces mae [kcal/mol/Å]    0.025    0.025
# epoch:  233                    train:   valid:
#     loss [a.u.]                0.002    0.002
#     energy mae [kcal/mol]      0.003    0.001
#     forces mae [kcal/mol/Å]    0.025    0.024
# epoch:  234                    train:   valid:
#     loss [a.u.]                0.002    0.001
#     energy mae [kcal/mol]      0.001    0.001
#     forces mae [kcal/mol/Å]    0.024    0.023
# epoch:  235                    train:   valid:
#     loss [a.u.]                0.002    0.001
#     energy mae [kcal/mol]      0.002    0.001
#     forces mae [kcal/mol/Å]    0.024    0.023
# epoch:  236                    train:   valid:
#     loss [a.u.]                0.002    0.001
#     energy mae [kcal/mol]      0.002    0.001
#     forces mae [kcal/mol/Å]    0.023    0.023
# epoch:  237                    train:   valid:
#     loss [a.u.]                0.001    0.001
#     energy mae [kcal/mol]      0.002    0.001
#     forces mae [kcal/mol/Å]    0.023    0.022
# epoch:  238                    train:   valid:
#     loss [a.u.]                0.001    0.001
#     energy mae [kcal/mol]      0.002    0.002
#     forces mae [kcal/mol/Å]    0.022    0.022
# epoch:  239                    train:   valid:
#     loss [a.u.]                0.001    0.001
#     energy mae [kcal/mol]      0.001    0.001
#     forces mae [kcal/mol/Å]    0.022    0.021
# epoch:  240                    train:   valid:
#     loss [a.u.]                0.001    0.001
#     energy mae [kcal/mol]      0.003    0.006
#     forces mae [kcal/mol/Å]    0.022    0.021
# epoch:  241                    train:   valid:
#     loss [a.u.]                0.001    0.001
#     energy mae [kcal/mol]      0.003    0.001
#     forces mae [kcal/mol/Å]    0.021    0.021
# epoch:  242                    train:   valid:
#     loss [a.u.]                0.001    0.001
#     energy mae [kcal/mol]      0.002    0.001
#     forces mae [kcal/mol/Å]    0.021    0.020
# epoch:  243                    train:   valid:
#     loss [a.u.]                0.001    0.001
#     energy mae [kcal/mol]      0.002    0.001
#     forces mae [kcal/mol/Å]    0.021    0.020
# epoch:  244                    train:   valid:
#     loss [a.u.]                0.001    0.001
#     energy mae [kcal/mol]      0.002    0.004
#     forces mae [kcal/mol/Å]    0.020    0.020
# epoch:  245                    train:   valid:
#     loss [a.u.]                0.001    0.001
#     energy mae [kcal/mol]      0.003    0.001
#     forces mae [kcal/mol/Å]    0.020    0.019
# epoch:  246                    train:   valid:
#     loss [a.u.]                0.001    0.001
#     energy mae [kcal/mol]      0.002    0.003
#     forces mae [kcal/mol/Å]    0.019    0.019
# epoch:  247                    train:   valid:
#     loss [a.u.]                0.001    0.001
#     energy mae [kcal/mol]      0.002    0.004
#     forces mae [kcal/mol/Å]    0.020    0.018
# epoch:  248                    train:   valid:
#     loss [a.u.]                0.001    0.001
#     energy mae [kcal/mol]      0.002    0.003
#     forces mae [kcal/mol/Å]    0.019    0.019
# epoch:  249                    train:   valid:
#     loss [a.u.]                0.001    0.001
#     energy mae [kcal/mol]      0.003    0.002
#     forces mae [kcal/mol/Å]    0.019    0.018
# epoch:  250                    train:   valid:
#     loss [a.u.]                0.001    0.001
#     energy mae [kcal/mol]      0.002    0.002
#     forces mae [kcal/mol/Å]    0.019    0.018
# epoch:  251                    train:   valid:
#     loss [a.u.]                0.001    0.001
#     energy mae [kcal/mol]      0.002    0.001
#     forces mae [kcal/mol/Å]    0.018    0.018
# epoch:  252                    train:   valid:
#     loss [a.u.]                0.001    0.001
#     energy mae [kcal/mol]      0.002    0.003
#     forces mae [kcal/mol/Å]    0.018    0.018
# epoch:  253                    train:   valid:
#     loss [a.u.]                0.001    0.001
#     energy mae [kcal/mol]      0.002    0.001
#     forces mae [kcal/mol/Å]    0.018    0.018
# epoch:  254                    train:   valid:
#     loss [a.u.]                0.001    0.001
#     energy mae [kcal/mol]      0.002    0.003
#     forces mae [kcal/mol/Å]    0.018    0.018
# epoch:  255                    train:   valid:
#     loss [a.u.]                0.001    0.001
#     energy mae [kcal/mol]      0.002    0.002
#     forces mae [kcal/mol/Å]    0.018    0.018
# epoch:  256                    train:   valid:
#     loss [a.u.]                0.001    0.001
#     energy mae [kcal/mol]      0.002    0.002
#     forces mae [kcal/mol/Å]    0.018    0.018
# epoch:  257                    train:   valid:
#     loss [a.u.]                0.001    0.001
#     energy mae [kcal/mol]      0.002    0.003
#     forces mae [kcal/mol/Å]    0.018    0.017
# epoch:  258                    train:   valid:
#     loss [a.u.]                0.001    0.001
#     energy mae [kcal/mol]      0.002    0.002
#     forces mae [kcal/mol/Å]    0.017    0.018
# epoch:  259                    train:   valid:
#     loss [a.u.]                0.001    0.001
#     energy mae [kcal/mol]      0.002    0.001
#     forces mae [kcal/mol/Å]    0.018    0.017
# epoch:  260                    train:   valid:
#     loss [a.u.]                0.001    0.001
#     energy mae [kcal/mol]      0.002    0.001
# ...
#     forces mae [kcal/mol/Å]    0.002    0.003
# epoch:  915                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.004    0.000
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  916                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.002    0.003
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  917                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.003    0.001
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  918                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.002    0.006
#     forces mae [kcal/mol/Å]    0.002    0.003
# epoch:  919                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.003    0.001
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  920                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.003    0.009
#     forces mae [kcal/mol/Å]    0.002    0.003
# epoch:  921                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.003    0.004
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  922                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.002    0.001
#     forces mae [kcal/mol/Å]    0.002    0.003
# epoch:  923                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.003    0.001
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  924                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.003    0.003
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  925                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.002    0.002
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  926                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.004    0.000
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  927                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.003    0.002
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  928                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.002    0.002
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  929                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.003    0.000
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  930                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.002    0.005
#     forces mae [kcal/mol/Å]    0.003    0.003
# epoch:  931                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.004    0.004
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  932                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.001    0.001
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  933                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.001    0.001
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  934                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.005    0.002
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  935                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.002    0.002
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  936                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.002    0.000
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  937                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.001    0.000
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  938                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.004    0.001
#     forces mae [kcal/mol/Å]    0.002    0.003
# epoch:  939                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.002    0.001
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  940                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.003    0.004
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  941                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.004    0.002
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  942                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.003    0.002
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  943                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.002    0.005
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  944                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.003    0.001
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  945                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.001    0.007
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  946                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.006    0.002
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  947                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.002    0.002
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  948                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.001    0.000
#     forces mae [kcal/mol/Å]    0.002    0.003
# epoch:  949                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.001    0.000
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  950                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.002    0.002
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  951                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.004    0.004
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  952                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.001    0.003
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  953                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.002    0.000
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  954                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.004    0.000
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  955                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.002    0.006
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  956                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.003    0.000
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  957                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.002    0.003
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  958                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.003    0.002
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  959                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.004    0.002
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  960                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.002    0.004
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  961                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.003    0.002
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  962                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.003    0.004
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  963                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.003    0.000
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  964                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.001    0.001
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  965                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.003    0.014
#     forces mae [kcal/mol/Å]    0.002    0.003
# epoch:  966                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.005    0.001
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  967                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.001    0.000
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  968                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.001    0.003
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  969                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.001    0.000
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  970                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.002    0.003
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  971                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.005    0.001
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  972                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.001    0.001
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  973                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.003    0.001
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  974                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.002    0.001
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  975                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.002    0.009
#     forces mae [kcal/mol/Å]    0.002    0.003
# epoch:  976                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.005    0.000
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  977                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.001    0.002
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  978                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.001    0.000
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  979                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.003    0.001
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  980                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.003    0.006
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  981                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.003    0.001
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  982                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.002    0.007
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  983                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.004    0.001
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  984                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.002    0.001
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  985                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.002    0.004
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  986                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.004    0.002
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  987                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.001    0.001
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  988                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.004    0.000
#     forces mae [kcal/mol/Å]    0.002    0.003
# epoch:  989                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.001    0.002
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  990                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.005    0.005
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  991                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.001    0.002
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  992                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.001    0.001
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  993                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.005    0.001
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  994                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.003    0.002
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  995                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.001    0.001
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  996                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.002    0.002
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  997                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.002    0.001
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  998                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.003    0.010
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  999                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.003    0.001
#     forces mae [kcal/mol/Å]    0.002    0.002
# epoch:  1000                    train:   valid:
#     loss [a.u.]                0.000    0.000
#     energy mae [kcal/mol]      0.002    0.005
#     forces mae [kcal/mol/Å]    0.002    0.002

# %%
import pickle
# open a file, where you ant to store the data
with open('params.pkl', 'wb') as file:
    pickle.dump(params, file)

# %%
import pandas as pd
params = pd.read_pickle("params.pkl")

# %%
message_passing_model
# Out:
# MessagePassingModel(
#     # attributes
#     features = 32
#     max_degree = 2
#     num_iterations = 3
#     num_basis_functions = 16
#     cutoff = 5.0
#     max_atomic_number = 118
# )

# %%
! pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.8.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.49.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (159 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.1/159.1 kB 8.3 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.4.5-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy<2,>=1.21 in /home/boittier/psi4conda/envs/jaxe3xcuda11py39/lib/python3.9/site-packages (from matplotlib) (1.26.3)
# Requirement already satisfied: packaging>=20.0 in /home/boittier/psi4conda/envs/jaxe3xcuda11py39/lib/python3.9/site-packages (from matplotlib) (23.2)
# Collecting pillow>=8 (from matplotlib)
#   Using cached pillow-10.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.7 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Using cached pyparsing-3.1.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/boittier/psi4conda/envs/jaxe3xcuda11py39/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/boittier/psi4conda/envs/jaxe3xcuda11py39/lib/python3.9/site-packages (from matplotlib) (6.1.1)
# Requirement already satisfied: zipp>=3.1.0 in /home/boittier/psi4conda/envs/jaxe3xcuda11py39/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.17.0)
# Requirement already satisfied: six>=1.5 in /home/boittier/psi4conda/envs/jaxe3xcuda11py39/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.8.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 46.0 MB/s eta 0:00:00:00:0100:01
# Using cached contourpy-1.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (310 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.49.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 46.7 MB/s eta 0:00:00:00:0100:01
# Using cached kiwisolver-1.4.5-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
# Using cached pillow-10.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.4 MB)
# Using cached pyparsing-3.1.1-py3-none-any.whl (103 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dscribe 2.1.0 requires joblib>=1.0.0, which is not installed.
# dscribe 2.1.0 requires scikit-learn, which is not installed.
# Successfully installed contourpy-1.2.0 cycler-0.12.1 fonttools-4.49.0 kiwisolver-1.4.5 matplotlib-3.8.3 pillow-10.2.0 pyparsing-3.1.1

# %%
! pip install py3dmol
# Out:
# Collecting py3dmol
#   Using cached py3Dmol-2.0.4-py2.py3-none-any.whl.metadata (2.1 kB)
# Using cached py3Dmol-2.0.4-py2.py3-none-any.whl (12 kB)
# Installing collected packages: py3dmol
# Successfully installed py3dmol-2.0.4

# %%
import io
import ase
import ase.calculators.calculator as ase_calc
import ase.io as ase_io
from ase.md.velocitydistribution import MaxwellBoltzmannDistribution, Stationary, ZeroRotation
from ase.md.verlet import VelocityVerlet
import ase.optimize as ase_opt
import matplotlib.pyplot as plt
import py3Dmol

# %% [markdown]
# Before we can use our model as a `Calculator` in ASE, we need to write a small interface. The following implementation is very bare bones, but it does the trick for a few simple demonstrations.

# %%
@jax.jit
def evaluate_energies_and_forces(atomic_numbers, positions, dst_idx, src_idx):
  return message_passing_model.apply(params, 
    atomic_numbers=atomic_numbers,
    positions=positions,
    dst_idx=dst_idx,
    src_idx=src_idx,
  )


class MessagePassingCalculator(ase_calc.Calculator):
  implemented_properties = ["energy", "forces"]

  def calculate(self, atoms, properties, system_changes = ase.calculators.calculator.all_changes):
    ase_calc.Calculator.calculate(self, atoms, properties, system_changes)
    dst_idx, src_idx = e3x.ops.sparse_pairwise_indices(len(atoms))
    energy, forces = evaluate_energies_and_forces(
      atomic_numbers=atoms.get_atomic_numbers(), 
      positions=atoms.get_positions(), 
      dst_idx=dst_idx, 
      src_idx=src_idx
    )
    # self.results['energy'] = energy * ase.units.kcal/ase.units.mol
    # self.results['forces'] = forces * ase.units.kcal/ase.units.mol
    self.results['energy'] = energy #* ase.units.kcal/ase.units.mol
    self.results['forces'] = forces #* ase.units.kcal/ase.units.mol

# %% [markdown]
# At first, let's find an optimized structure for ethanol. We arbitrarily initialize the structure to some entry in our training data and then use ASE's `BFGS` optimizer to optimize it.

# %%
atoms = ase.Atoms(valid_data['atomic_numbers'][0], valid_data['positions'][0])

# %%
eV2Har = 0.0367492929 
Eref_H = -0.499946213283
Eref_O = -75.000839553994
Eref_H2O = 2 * Eref_H + Eref_O

# %%
valid_results = []

for i in range(len(valid_data["atomic_numbers"])):
    atoms = ase.Atoms(valid_data['atomic_numbers'][i], valid_data['positions'][i])
    atoms.set_calculator(MessagePassingCalculator())
    pred = atoms.get_total_energy()[0] * eV2Har
    actual = valid_data['energy'][i] * eV2Har
    prediction = pred + Eref_H2O
    ground_truth = actual + Eref_H2O
    diff = (pred - actual) * 627.509
    valid_results.append((prediction, ground_truth))

# %%
valid_batches = prepare_batches(data_key, valid_data, len(valid_data["atomic_numbers"]))

# %%
valid_energies = valid_batches[0]["energy"]* eV2Har + Eref_H2O

# %%
batch = valid_batches[0]
energy, forces = message_passing_model.apply(
    params,
    atomic_numbers=batch['atomic_numbers'],
    positions=batch['positions'],
    dst_idx=batch['dst_idx'],
    src_idx=batch['src_idx'],
    batch_segments=batch['batch_segments'],
    batch_size=len(valid_data["atomic_numbers"])
)

# %%
valid_predictions = energy * eV2Har + Eref_H2O

# %%
valid_results = np.array(valid_results)

# %%
# !pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.4.1.post1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.0,>=1.19.5 in /home/boittier/psi4conda/envs/jaxe3xcuda11py39/lib/python3.9/site-packages (from scikit-learn) (1.26.3)
# Requirement already satisfied: scipy>=1.6.0 in /home/boittier/psi4conda/envs/jaxe3xcuda11py39/lib/python3.9/site-packages (from scikit-learn) (1.12.0)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Using cached joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn)
#   Downloading threadpoolctl-3.3.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.4.1.post1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 45.0 MB/s eta 0:00:00:00:01:01
# Using cached joblib-1.3.2-py3-none-any.whl (302 kB)
# Downloading threadpoolctl-3.3.0-py3-none-any.whl (17 kB)
# Installing collected packages: threadpoolctl, joblib, scikit-learn

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
def plot_xy(pred, gt):
    mae = mean_absolute_error(pred, gt) * 627.509
    rmse = np.sqrt(mean_squared_error(pred, gt)) * 627.509
    plt.title(f"MAE: {mae:.3f} kcal/mol, RMSE: {rmse:.3f} kcal/mol")
    plt.scatter(pred, gt, alpha=0.5)
    _min = min([np.min(pred), np.min(gt)])
    _max = max([np.max(pred), np.max(gt)])
    ax = plt.gca()
    ax.set_xlim(_min, _max)
    ax.set_ylim(_min, _max)
    ax.plot([_min, _max], [_min, _max], color="k")
    ax.set_aspect("equal")

# %%
plot_xy(valid_predictions, valid_energies)

# %%
pred, gt = valid_results.T

# %%
# Initialize atoms object and attach calculator.
# atoms = ase.Atoms(train_data['atomic_numbers'][0], train_data['positions'][0])
atoms = ase.Atoms([1,1,8], [[0.000,   0.939,  0.243], [0,0,0.97], [0,0,0]])

atoms.set_calculator(MessagePassingCalculator())

# Run structure optimization with BFGS.
_ = ase_opt.BFGS(atoms).run(fmax=0.005)
# Out:
#       Step     Time          Energy         fmax
# BFGS:    0 13:30:08       -9.290279        3.7251
# BFGS:    1 13:30:08       -9.637012        2.2709
# BFGS:    2 13:30:08      -10.007947        0.2220
# BFGS:    3 13:30:08      -10.008667        0.0099
# BFGS:    4 13:30:08      -10.008674        0.0020

# %% [markdown]
# A promising start! Note that ASE uses electron volts (eV) as energy units, so the final structure has an energy that is lower by roughly 0.6 eV, or about 14 kcal/mol. Let's check how the optimized structure looks.

# %%
# Write structure to xyz file.
xyz = io.StringIO()
ase_io.write(xyz, atoms, format='xyz')

# Visualize the structure with py3Dmol.
view = py3Dmol.view()
view.addModel(xyz.getvalue(), 'xyz')
view.setStyle({'stick': {'radius': 0.15}, 'sphere': {'scale': 0.25}})
view.show()
# Out:
# <div id="3dmolviewer_17091234089923618"  style="position: relative; width: 640px; height: 480px;">
#         <p id="3dmolwarning_17091234089923618" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.0.4/3Dmol-min.js');
# }
#
# var viewer_17091234089923618 = null;
# var warn = document.getElementById("3dmolwarning_17091234089923618");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17091234089923618 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17091234089923618"),{backgroundColor:"white"});
# viewer_17091234089923618.zoomTo();
# 	viewer_17091234089923618.addModel("3\n\nH      -0.000000000000000      1.032482461671571      0.095775498777547\nH      -0.000000000000000     -0.165945641945178      1.023567245764057\nO       0.000000000000000      0.072463179085136      0.093657263665839\n","xyz");
# 	viewer_17091234089923618.setStyle({"stick": {"radius": 0.15}, "sphere": {"scale": 0.25}});
# viewer_17091234089923618.render();
# });
# </script>

# %% [markdown]
# Now let's try to run a molecular dynamics simulation. We draw initial momenta from a Maxwell-Boltzmann distribution at 300 K, remove center of mass translation and rotation, and then use Verlet integration to integrate the equations of motion for 2000 steps using a timestep of 0.5 fs. For visualization purposes, we also save each frame and keep track of potential, kinetic, and total energies.

# %%
# Parameters.
temperature = 300
timestep_fs = 0.1
num_steps = 20000

# Draw initial momenta.
MaxwellBoltzmannDistribution(atoms, temperature_K=temperature)
Stationary(atoms)  # Remove center of mass translation.
ZeroRotation(atoms)  # Remove rotations.

# Initialize Velocity Verlet integrator.
integrator = VelocityVerlet(atoms, timestep=timestep_fs*ase.units.fs)

# Run molecular dynamics.
frames = np.zeros((num_steps, len(atoms), 3))
potential_energy = np.zeros((num_steps,))
kinetic_energy = np.zeros((num_steps,))
total_energy = np.zeros((num_steps,))
for i in range(num_steps):
  # Run 1 time step.  
  integrator.run(1)  
  # Save current frame and keep track of energies.
  frames[i] = atoms.get_positions()
  potential_energy[i] = atoms.get_potential_energy()
  kinetic_energy[i] = atoms.get_kinetic_energy()
  total_energy[i] = atoms.get_total_energy()
  # Occasionally print progress.
  if i % 100 == 0:
    print(f"step {i:5d} epot {potential_energy[i]: 5.3f} ekin {kinetic_energy[i]: 5.3f} etot {total_energy[i]: 5.3f}")
# Out:
# /tmp/ipykernel_6984/162200113.py:24: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future.
#   potential_energy[i] = atoms.get_potential_energy()
# /tmp/ipykernel_6984/162200113.py:26: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future.
#   total_energy[i] = atoms.get_total_energy()
# step     0 epot -9.959 ekin  0.150 etot -9.810
# step   100 epot -9.941 ekin  0.131 etot -9.810
# step   200 epot -9.822 ekin  0.012 etot -9.810
# step   300 epot -9.984 ekin  0.174 etot -9.810
# step   400 epot -9.899 ekin  0.089 etot -9.810
# step   500 epot -9.823 ekin  0.014 etot -9.810
# step   600 epot -9.978 ekin  0.168 etot -9.810
# step   700 epot -9.909 ekin  0.099 etot -9.810
# step   800 epot -9.838 ekin  0.028 etot -9.810
# step   900 epot -9.990 ekin  0.180 etot -9.810
# step  1000 epot -9.872 ekin  0.063 etot -9.810
# step  1100 epot -9.839 ekin  0.030 etot -9.810
# step  1200 epot -9.982 ekin  0.172 etot -9.810
# step  1300 epot -9.880 ekin  0.071 etot -9.810
# step  1400 epot -9.862 ekin  0.052 etot -9.810
# step  1500 epot -9.981 ekin  0.172 etot -9.810
# step  1600 epot -9.855 ekin  0.046 etot -9.810
# step  1700 epot -9.858 ekin  0.048 etot -9.810
# step  1800 epot -9.980 ekin  0.170 etot -9.810
# step  1900 epot -9.859 ekin  0.050 etot -9.810
# step  2000 epot -9.884 ekin  0.074 etot -9.810
# step  2100 epot -9.971 ekin  0.162 etot -9.810
# step  2200 epot -9.841 ekin  0.032 etot -9.810
# step  2300 epot -9.875 ekin  0.066 etot -9.810
# step  2400 epot -9.979 ekin  0.169 etot -9.810
# step  2500 epot -9.840 ekin  0.031 etot -9.810
# step  2600 epot -9.905 ekin  0.096 etot -9.810
# step  2700 epot -9.963 ekin  0.153 etot -9.810
# step  2800 epot -9.827 ekin  0.017 etot -9.810
# step  2900 epot -9.895 ekin  0.085 etot -9.810
# step  3000 epot -9.977 ekin  0.167 etot -9.810
# step  3100 epot -9.821 ekin  0.012 etot -9.810
# step  3200 epot -9.931 ekin  0.122 etot -9.810
# step  3300 epot -9.951 ekin  0.141 etot -9.810
# step  3400 epot -9.814 ekin  0.005 etot -9.810
# step  3500 epot -9.921 ekin  0.112 etot -9.810
# step  3600 epot -9.967 ekin  0.157 etot -9.810
# step  3700 epot -9.811 ekin  0.002 etot -9.810
# step  3800 epot -9.960 ekin  0.151 etot -9.810
# step  3900 epot -9.929 ekin  0.119 etot -9.810
# step  4000 epot -9.812 ekin  0.003 etot -9.810
# step  4100 epot -9.949 ekin  0.139 etot -9.810
# step  4200 epot -9.943 ekin  0.133 etot -9.810
# step  4300 epot -9.820 ekin  0.011 etot -9.810
# step  4400 epot -9.979 ekin  0.169 etot -9.810
# step  4500 epot -9.904 ekin  0.095 etot -9.810
# step  4600 epot -9.825 ekin  0.016 etot -9.810
# step  4700 epot -9.966 ekin  0.156 etot -9.810
# step  4800 epot -9.917 ekin  0.107 etot -9.810
# step  4900 epot -9.841 ekin  0.032 etot -9.810
# step  5000 epot -9.985 ekin  0.175 etot -9.810
# step  5100 epot -9.887 ekin  0.077 etot -9.810
# step  5200 epot -9.843 ekin  0.033 etot -9.810
# step  5300 epot -9.977 ekin  0.167 etot -9.810
# step  5400 epot -9.896 ekin  0.087 etot -9.810
# step  5500 epot -9.862 ekin  0.053 etot -9.810
# step  5600 epot -9.987 ekin  0.177 etot -9.810
# step  5700 epot -9.871 ekin  0.062 etot -9.810
# step  5800 epot -9.859 ekin  0.050 etot -9.810
# step  5900 epot -9.988 ekin  0.178 etot -9.810
# step  6000 epot -9.877 ekin  0.067 etot -9.810
# step  6100 epot -9.884 ekin  0.074 etot -9.810
# step  6200 epot -9.990 ekin  0.180 etot -9.810
# step  6300 epot -9.854 ekin  0.045 etot -9.810
# step  6400 epot -9.876 ekin  0.066 etot -9.810
# step  6500 epot -9.998 ekin  0.189 etot -9.810
# step  6600 epot -9.855 ekin  0.045 etot -9.810
# step  6700 epot -9.911 ekin  0.101 etot -9.810
# step  6800 epot -9.990 ekin  0.180 etot -9.810
# step  6900 epot -9.837 ekin  0.027 etot -9.810
# step  7000 epot -9.899 ekin  0.089 etot -9.810
# step  7100 epot -9.997 ekin  0.188 etot -9.810
# step  7200 epot -9.834 ekin  0.025 etot -9.810
# step  7300 epot -9.943 ekin  0.133 etot -9.810
# step  7400 epot -9.976 ekin  0.166 etot -9.810
# step  7500 epot -9.829 ekin  0.020 etot -9.810
# step  7600 epot -9.928 ekin  0.118 etot -9.810
# step  7700 epot -9.979 ekin  0.170 etot -9.810
# step  7800 epot -9.829 ekin  0.020 etot -9.810
# step  7900 epot -9.968 ekin  0.158 etot -9.810
# step  8000 epot -9.952 ekin  0.142 etot -9.810
# step  8100 epot -9.835 ekin  0.026 etot -9.810
# step  8200 epot -9.952 ekin  0.142 etot -9.810
# step  8300 epot -9.957 ekin  0.147 etot -9.810
# step  8400 epot -9.837 ekin  0.028 etot -9.810
# step  8500 epot -9.980 ekin  0.170 etot -9.810
# step  8600 epot -9.929 ekin  0.119 etot -9.810
# step  8700 epot -9.843 ekin  0.033 etot -9.810
# step  8800 epot -9.968 ekin  0.158 etot -9.810
# step  8900 epot -9.936 ekin  0.126 etot -9.810
# step  9000 epot -9.848 ekin  0.039 etot -9.810
# step  9100 epot -9.989 ekin  0.179 etot -9.810
# step  9200 epot -9.908 ekin  0.098 etot -9.810
# step  9300 epot -9.849 ekin  0.040 etot -9.810
# step  9400 epot -9.981 ekin  0.172 etot -9.810
# step  9500 epot -9.912 ekin  0.102 etot -9.810
# step  9600 epot -9.858 ekin  0.048 etot -9.810
# step  9700 epot -9.998 ekin  0.188 etot -9.810
# step  9800 epot -9.886 ekin  0.077 etot -9.810
# step  9900 epot -9.857 ekin  0.047 etot -9.810
# step 10000 epot -9.996 ekin  0.186 etot -9.810
# step 10100 epot -9.882 ekin  0.072 etot -9.810
# step 10200 epot -9.871 ekin  0.062 etot -9.810
# step 10300 epot -10.001 ekin  0.192 etot -9.810
# step 10400 epot -9.861 ekin  0.051 etot -9.810
# step 10500 epot -9.873 ekin  0.063 etot -9.810
# step 10600 epot -10.004 ekin  0.194 etot -9.810
# step 10700 epot -9.852 ekin  0.043 etot -9.810
# step 10800 epot -9.896 ekin  0.086 etot -9.810
# step 10900 epot -9.989 ekin  0.179 etot -9.810
# step 11000 epot -9.839 ekin  0.030 etot -9.810
# step 11100 epot -9.896 ekin  0.086 etot -9.810
# step 11200 epot -9.994 ekin  0.184 etot -9.810
# step 11300 epot -9.836 ekin  0.026 etot -9.810
# step 11400 epot -9.924 ekin  0.114 etot -9.810
# step 11500 epot -9.965 ekin  0.155 etot -9.810
# step 11600 epot -9.831 ekin  0.021 etot -9.810
# step 11700 epot -9.916 ekin  0.106 etot -9.810
# step 11800 epot -9.974 ekin  0.164 etot -9.810
# step 11900 epot -9.831 ekin  0.021 etot -9.810
# step 12000 epot -9.944 ekin  0.134 etot -9.810
# step 12100 epot -9.942 ekin  0.132 etot -9.810
# step 12200 epot -9.828 ekin  0.018 etot -9.810
# step 12300 epot -9.932 ekin  0.123 etot -9.810
# step 12400 epot -9.954 ekin  0.144 etot -9.810
# step 12500 epot -9.828 ekin  0.018 etot -9.810
# step 12600 epot -9.958 ekin  0.148 etot -9.810
# step 12700 epot -9.921 ekin  0.112 etot -9.810
# step 12800 epot -9.825 ekin  0.016 etot -9.810
# step 12900 epot -9.949 ekin  0.140 etot -9.810
# step 13000 epot -9.933 ekin  0.124 etot -9.810
# step 13100 epot -9.827 ekin  0.017 etot -9.810
# step 13200 epot -9.973 ekin  0.163 etot -9.810
# step 13300 epot -9.899 ekin  0.089 etot -9.810
# step 13400 epot -9.824 ekin  0.014 etot -9.810
# step 13500 epot -9.970 ekin  0.160 etot -9.810
# step 13600 epot -9.907 ekin  0.097 etot -9.810
# step 13700 epot -9.833 ekin  0.023 etot -9.810
# step 13800 epot -9.987 ekin  0.178 etot -9.810
# step 13900 epot -9.872 ekin  0.062 etot -9.810
# step 14000 epot -9.832 ekin  0.022 etot -9.810
# step 14100 epot -9.987 ekin  0.177 etot -9.810
# step 14200 epot -9.875 ekin  0.066 etot -9.810
# step 14300 epot -9.854 ekin  0.045 etot -9.810
# step 14400 epot -9.989 ekin  0.179 etot -9.810
# step 14500 epot -9.849 ekin  0.039 etot -9.810
# step 14600 epot -9.854 ekin  0.044 etot -9.810
# step 14700 epot -9.988 ekin  0.178 etot -9.810
# step 14800 epot -9.852 ekin  0.042 etot -9.810
# step 14900 epot -9.884 ekin  0.074 etot -9.810
# step 15000 epot -9.975 ekin  0.166 etot -9.810
# step 15100 epot -9.837 ekin  0.028 etot -9.810
# step 15200 epot -9.878 ekin  0.068 etot -9.810
# step 15300 epot -9.980 ekin  0.170 etot -9.810
# step 15400 epot -9.840 ekin  0.030 etot -9.810
# step 15500 epot -9.909 ekin  0.100 etot -9.810
# step 15600 epot -9.961 ekin  0.151 etot -9.810
# step 15700 epot -9.831 ekin  0.021 etot -9.810
# step 15800 epot -9.900 ekin  0.090 etot -9.810
# step 15900 epot -9.971 ekin  0.161 etot -9.810
# step 16000 epot -9.831 ekin  0.021 etot -9.810
# step 16100 epot -9.932 ekin  0.123 etot -9.810
# step 16200 epot -9.948 ekin  0.138 etot -9.810
# step 16300 epot -9.825 ekin  0.016 etot -9.810
# step 16400 epot -9.923 ekin  0.113 etot -9.810
# step 16500 epot -9.963 ekin  0.154 etot -9.810
# step 16600 epot -9.823 ekin  0.013 etot -9.810
# step 16700 epot -9.957 ekin  0.147 etot -9.810
# step 16800 epot -9.933 ekin  0.123 etot -9.810
# step 16900 epot -9.820 ekin  0.011 etot -9.810
# step 17000 epot -9.951 ekin  0.141 etot -9.810
# step 17100 epot -9.949 ekin  0.140 etot -9.810
# step 17200 epot -9.822 ekin  0.012 etot -9.810
# step 17300 epot -9.983 ekin  0.173 etot -9.810
# step 17400 epot -9.910 ekin  0.101 etot -9.810
# step 17500 epot -9.823 ekin  0.014 etot -9.810
# step 17600 epot -9.977 ekin  0.167 etot -9.810
# step 17700 epot -9.924 ekin  0.114 etot -9.810
# step 17800 epot -9.838 ekin  0.029 etot -9.810
# step 17900 epot -9.998 ekin  0.188 etot -9.810
# step 18000 epot -9.887 ekin  0.077 etot -9.810
# step 18100 epot -9.841 ekin  0.031 etot -9.810
# step 18200 epot -9.989 ekin  0.179 etot -9.810
# step 18300 epot -9.897 ekin  0.088 etot -9.810
# step 18400 epot -9.866 ekin  0.056 etot -9.810
# step 18500 epot -9.997 ekin  0.187 etot -9.810
# step 18600 epot -9.872 ekin  0.062 etot -9.810
# step 18700 epot -9.864 ekin  0.054 etot -9.810
# step 18800 epot -9.992 ekin  0.182 etot -9.810
# step 18900 epot -9.878 ekin  0.068 etot -9.810
# step 19000 epot -9.891 ekin  0.082 etot -9.810
# step 19100 epot -9.990 ekin  0.180 etot -9.810
# step 19200 epot -9.860 ekin  0.051 etot -9.810
# step 19300 epot -9.885 ekin  0.075 etot -9.810
# step 19400 epot -9.994 ekin  0.184 etot -9.810
# step 19500 epot -9.862 ekin  0.052 etot -9.810
# step 19600 epot -9.915 ekin  0.105 etot -9.810
# step 19700 epot -9.983 ekin  0.174 etot -9.810
# step 19800 epot -9.847 ekin  0.037 etot -9.810
# step 19900 epot -9.904 ekin  0.094 etot -9.810

# %% [markdown]
# Let's have a look at the trajectory.

# %%
# view.getModel().setCoordinates(frames, 'array')
# view.animate({'loop': 'forward', 'interval': 0.1})
# view.show()

# %% [markdown]
# This looks reasonable. As a final check, let's plot the potential, kinetic, and total energies.

# %%
# %matplotlib inline
plt.subplots_adjust(left=0, right=1, bottom=0, top=1)
plt.xlabel('time [fs]')
plt.ylabel('energy [eV]')
time = np.arange(num_steps) * timestep_fs
plt.plot(time, potential_energy, label='potential energy')
plt.plot(time, kinetic_energy, label='kinetic energy')
plt.plot(time, total_energy, label='total energy')
plt.legend()
plt.grid()

# %%
# %matplotlib inline
plt.hist(total_energy - total_energy.mean())
# Out:
# (array([1236., 3355., 1958., 1733., 1613., 1684., 1901., 2541., 3114.,
#          865.]),
#  array([-1.44654083e-04, -1.15471649e-04, -8.62892151e-05, -5.71067810e-05,
#         -2.79243469e-05,  1.25808716e-06,  3.04405212e-05,  5.96229553e-05,
#          8.88053894e-05,  1.17987823e-04,  1.47170258e-04]),
#  <BarContainer object of 10 artists>)

# %%
plt.plot(time, total_energy - total_energy.mean(), label='total energy')

# %%
valid_data
# Out:
# {'energy': Array([ -9.996439, -10.001525, -10.002346, ...,  -9.977668,  -9.934   ,
#          -9.993609], dtype=float32),
#  'forces': Array([[[-6.5885603e-02, -6.4526540e-01, -3.9915371e-01],
#          [ 1.3991261e-01,  8.8042873e-01,  4.1318083e-01],
#          [-7.4027002e-02, -2.3516335e-01, -1.4027117e-02]],
#
#         [[-2.2968233e-02, -1.0148998e-01, -5.9734907e-02],
#          [-2.8016242e-01,  7.9990053e-01, -2.7281436e-01],
#          [ 3.0313066e-01, -6.9841057e-01,  3.3254927e-01]],
#
#         [[-1.4282453e-01, -3.2292780e-01, -4.5436352e-01],
#          [ 4.9119413e-01,  4.1359469e-01,  2.2115341e-01],
#          [-3.4836960e-01, -9.0666927e-02,  2.3321013e-01]],
#
#         ...,
#
#         [[-0.0000000e+00,  8.3985603e-01,  2.3071554e-01],
#          [-0.0000000e+00,  4.1548428e-01,  2.3524639e-01],
#          [ 0.0000000e+00, -1.2553403e+00, -4.6596193e-01]],
#
#         [[-0.0000000e+00,  1.4266264e+00, -1.0511110e+00],
#          [-0.0000000e+00, -2.0626080e+00,  1.0508127e+00],
#          [ 0.0000000e+00,  6.3598150e-01,  2.9824799e-04]],
#
#         [[-4.4378036e-01,  4.3171710e-01, -3.9807478e-01],
#          [ 1.5644228e-01, -1.1715608e-01,  1.8449143e-01],
#          [ 2.8733808e-01, -3.1456101e-01,  2.1358335e-01]]], dtype=float32),
#  'atomic_numbers': Array([[1, 8, 1],
#         [1, 8, 1],
#         [1, 8, 1],
#         ...,
#         [8, 1, 1],
#         [8, 1, 1],
#         [1, 8, 1]], dtype=int32),
#  'positions': Array([[[-5.382280e+00, -1.345107e+01,  1.424488e+01],
#          [-5.348800e+00, -1.413529e+01,  1.355004e+01],
#          [-4.915260e+00, -1.365886e+01,  1.283324e+01]],
#
#         [[-6.400080e+00, -1.370671e+01, -1.240351e+01],
#          [-6.688500e+00, -1.438484e+01, -1.302024e+01],
#          [-6.356650e+00, -1.519460e+01, -1.266629e+01]],
#
#         [[-1.475276e+01,  6.933000e-02, -5.088090e+00],
#          [-1.494892e+01, -4.604100e-01, -5.878070e+00],
#          [-1.418861e+01, -2.978800e-01, -6.455080e+00]],
#
#         ...,
#
#         [[ 0.000000e+00, -1.594900e-03,  1.226740e-01],
#          [ 0.000000e+00,  7.306821e-01, -4.961390e-01],
#          [ 0.000000e+00, -7.179229e-01, -4.852530e-01]],
#
#         [[ 0.000000e+00, -3.341100e-03,  1.160075e-01],
#          [ 0.000000e+00,  8.136429e-01, -4.754325e-01],
#          [ 0.000000e+00, -7.869141e-01, -4.526275e-01]],
#
#         [[-9.096400e+00,  6.500190e+00,  1.716419e+01],
#          [-8.604290e+00,  6.294120e+00,  1.794932e+01],
#          [-8.222040e+00,  5.454540e+00,  1.770262e+01]]], dtype=float32)}

# %%
plt.hist(valid_data["energy"])
# Out:
# (array([8.782e+03, 4.240e+02, 3.270e+02, 1.810e+02, 1.260e+02, 8.900e+01,
#         3.900e+01, 1.900e+01, 7.000e+00, 6.000e+00]),
#  array([-10.00796032,  -9.91153717,  -9.81511402,  -9.71869183,
#          -9.62226868,  -9.52584553,  -9.42942238,  -9.33299923,
#          -9.23657703,  -9.14015388,  -9.04373074]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(train_data["energy"])
# Out:
# (array([1.4874e+04, 7.3100e+02, 5.3700e+02, 3.5500e+02, 2.3100e+02,
#         1.2300e+02, 7.7000e+01, 3.6000e+01, 2.2000e+01, 4.0000e+00]),
#  array([-10.00797749,  -9.91140366,  -9.81482887,  -9.71825409,
#          -9.62168026,  -9.52510643,  -9.42853165,  -9.33195686,
#          -9.23538303,  -9.1388092 ,  -9.04223442]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# As expected, the potential and kinetic energies fluctuate during the trajectory. However, their sum, the total energy, is constant, as it should be (energy conservation). Tiny deviations in the total energy stem primarily from inaccuracies in the Velocity Verlet integration and can be reduced by choosing a smaller timestep.
